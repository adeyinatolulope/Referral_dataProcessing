# %%
import os

# Paste your key here (temporary session storage)
os.environ["GOOGLE_API_KEY"] = "AIzaSyBgI_vaGTppsp-P_UpLPOdRSDKAYI1uw8E"

GOOGLE_API_KEY = os.getenv("GOOGLE_API_KEY")
assert GOOGLE_API_KEY is not None, "API key is missing."

print("✔ Google Places API key loaded securely.")
# Out:
# ✔ Google Places API key loaded securely.

# %%
import requests
import pandas as pd
import time
from tqdm import tqdm

print("✔ Libraries imported")
# Out:
# ✔ Libraries imported

# %%
TARGET_LOCS = [
    {"city": "El Paso", "state": "TX"},
    {"city": "Las Cruces", "state": "NM"},
]

# Output
OUTPUT_XLSX = "/Users/arteriesveins/Desktop/Referral_code/referral_sources_elpaso_lascruces_master.xlsx"
OUTPUT_QC    = "/Users/arteriesveins/Desktop/Referral_code/referral_sources_elpaso_lascruces_qc.csv"

# NPI base
NPI_URL = "https://npiregistry.cms.hhs.gov/api/"
NPI_VERSION = "2.1"

# Rate-control
NPI_PAGE_LIMIT = 200
NPI_MAX_PAGES = 40
NPI_TIMEOUT = 20

GP_SLEEP = 0.15   # Places rate control
REQ_TIMEOUT = 20  # Seconds

# %%
# CLINICS that commonly send vascular referrals
CLINIC_TAXONOMIES = [
    "261Q00000X",  # Clinic/Center (general)
    "261QP2300X",  # Primary Care Clinic
    "261QM1300X",  # Multi-specialty
    "261QU0200X",  # Urgent Care
    "261QF0400X",  # FQHC
    "261QX0200X",  # Wound Care
    "261QR0400X",  # Rehab/Physical Therapy
    "261QR0200X",  # Radiology/Imaging
    "261QA0005X",  # Ambulatory Care
    "261QM0801X",  # Mental Health (may refer to vascular)
    "261QM2800X",  # Addiction (optional; can refer if vascular issues arise)
    "261QS1000X",  # Specialty outpatient
]

# PHYSICIANS relevant to vascular referrals
PHYSICIAN_TAX = [
    "207Q00000X",  # Family Medicine
    "207R00000X",  # Internal Medicine
    "208D00000X",  # General Practice
    "207RE0101X",  # Endocrinology
    "207RC0000X",  # Cardiology
    "207RI0011X",  # Interventional Cardiology
    "207LP2900X",  # Pain Medicine
    "207RN0300X",  # Nephrology
    "2086S0129X",  # Vascular Surgery
    "213E00000X",  # Podiatry
]

# HOSPITALS (to complete referral ecosystem)
HOSP_TAX = [
    "282N00000X",   # General Acute Care Hospital
    "282NC2000X",   # Critical Access Hospital
    "283X00000X",   # Rehabilitation Hospital
    # (You can add others if needed)
]

# Enumeration type filters
ENUM_ORG = "NPI-2"  # organizations (clinics, hospitals)
ENUM_IND = "NPI-1"  # individuals (physicians)

# %%
def npi_normalize(records):
    rows = []
    for r in records:

        # Safe accessors
        basic = r.get("basic", {}) or {}
        taxonomies = r.get("taxonomies") or [{}]
        addresses = r.get("addresses") or [{}]

        tax = taxonomies[0] if taxonomies else {}
        addr = addresses[0] if addresses else {}

        # Determine name: prefer organization name, fallback to person name
        name = basic.get("name")
        if not name:
            first = basic.get("first_name")
            last  = basic.get("last_name")
            name = " ".join([x for x in [first, last] if x])

        rows.append({
            "npi": r.get("number"),
            "entity_type": r.get("enumeration_type"),
            "name_npi": name,
            "practice_address_1": addr.get("address_1"),
            "practice_city": addr.get("city"),
            "practice_state": addr.get("state"),
            "practice_zip": addr.get("postal_code"),
            "taxonomy_code": tax.get("code"),
            "taxonomy_desc": tax.get("desc"),
        })

    # Return consistent dataframe with all required columns guaranteed
    df = pd.DataFrame(rows)

    # Force missing columns to exist
    required_cols = [
        "npi", "entity_type", "name_npi", "practice_address_1",
        "practice_city", "practice_state", "practice_zip",
        "taxonomy_code", "taxonomy_desc"
    ]
    for col in required_cols:
        if col not in df.columns:
            df[col] = None

    return df

# %%
dfs = []

for loc in TARGET_LOCS:
    state = loc["state"]
    print(f"\n📍 Fetching NPI data for {state}...")

    df_clin = fetch_block(state, CLINIC_TAXONOMIES, ENUM_ORG, "clinics")
    df_phys = fetch_block(state, PHYSICIAN_TAX, ENUM_IND, "physicians")
    df_hosp = fetch_block(state, HOSP_TAX, ENUM_ORG, "hospitals")

    dfs.extend([df_clin, df_phys, df_hosp])

df_npi = pd.concat(dfs, ignore_index=True)

print("\n🔎 Checking columns present:")
print(df_npi.columns)

# Force missing practice_city column if needed
if "practice_city" not in df_npi.columns:
    print("⚠️  practice_city column missing, creating empty fallback.")
    df_npi["practice_city"] = None

# Filter by target cities safely
cities_lower = {loc["city"].lower() for loc in TARGET_LOCS}

df_npi = df_npi[
    df_npi["practice_city"].astype(str).str.lower().isin(cities_lower)
]

df_npi.reset_index(drop=True, inplace=True)

print("\n✔ Filter complete. Total rows:", len(df_npi))
df_npi.head()
# Out:
# 📍 Fetching NPI data for TX...
# NPI clinics for TX: 100%|██████████| 12/12 [00:01<00:00,  9.25it/s]
# NPI physicians for TX: 100%|██████████| 10/10 [00:01<00:00,  9.96it/s]
# NPI hospitals for TX: 100%|██████████| 3/3 [00:00<00:00,  9.83it/s]
# 📍 Fetching NPI data for NM...
# NPI clinics for NM: 100%|██████████| 12/12 [00:01<00:00,  9.97it/s]
# NPI physicians for NM: 100%|██████████| 10/10 [00:01<00:00,  9.87it/s]
# NPI hospitals for NM: 100%|██████████| 3/3 [00:00<00:00,  9.91it/s]
# 🔎 Checking columns present:
# Index(['npi', 'entity_type', 'name_npi', 'practice_address_1', 'practice_city',
#        'practice_state', 'practice_zip', 'taxonomy_code', 'taxonomy_desc',
#        'source_block'],
#       dtype='object')
#
# ✔ Filter complete. Total rows: 0
# Empty DataFrame
# Columns: [npi, entity_type, name_npi, practice_address_1, practice_city, practice_state, practice_zip, taxonomy_code, taxonomy_desc, source_block]
# Index: []

# %%
import requests

# NOTE: This part requires a Google Cloud API Key
# You must enable the "Places API" for your project.

GOOGLE_API_KEY = "AIzaSyBgI_vaGTppsp-P_UpLPOdRSDKAYI1uw8E"

def fetch_google_places_data(query, location):
    """Fetches clinic data from Google Places API."""
    BASE_URL = "https://maps.googleapis.com/maps/api/place/textsearch/json"

    params = {
        'query': f"{query} in {location}",
        'key': GOOGLE_API_KEY,
    }

    response = requests.get(BASE_URL, params=params)
    if response.status_code == 200:
        data = response.json()
        google_results = []
        for item in data.get('results', []):
            record = {
                'Source': 'Google Places',
                'Name': item.get('name'),
                'Address': item.get('formatted_address'),
                'Place_ID': item.get('place_id'),
                'Business_Status': item.get('business_status')
            }
            google_results.append(record)
        return pd.DataFrame(google_results)

    return pd.DataFrame()

# %%
import requests
import pandas as pd
# Execute Google Places fetch (requires API Key)
google_df = fetch_google_places_data("Clinic OR Medical Center OR Hospital", "El Paso, TX")
print(f"Google Places Records Retrieved: {len(google_df)}")
# Out:
# Google Places Records Retrieved: 20

# %%
google_df
# Out:
#            Source                                               Name  \
# 0   Google Places                          Las Palmas Medical Center
# 1   Google Places               University Medical Center of El Paso
# 2   Google Places                             Del Sol Medical Center
# 3   Google Places          The Hospitals of Providence Sierra Campus
# 4   Google Places        The Hospitals of Providence Memorial Campus
# 5   Google Places             Del Sol Medical Center: Emergency Room
# 6   Google Places       The Hospitals of Providence Northeast Campus
# 7   Google Places                           Kindred Hospital El Paso
# 8   Google Places              Premier Specialty Hospital of El Paso
# 9   Google Places                             Paisano Medical Center
# 10  Google Places                          El Paso VA Medical Center
# 11  Google Places           Las Palmas Medical Center Emergency Room
# 12  Google Places                        El Paso Children’s Hospital
# 13  Google Places               University Medical Center Of El Paso
# 14  Google Places  University Medical Center of El Paso - Main Ca...
# 15  Google Places                   Texas Tech Physicians of El Paso
# 16  Google Places                        SCENIC POINT MEDICAL CENTER
# 17  Google Places  Texas Tech University Health Sciences Center E...
# 18  Google Places                 Village Medical - South Mesa Hills
# 19  Google Places                              United Medical Clinic
#
#                                               Address  \
# 0   1801 N Oregon St, El Paso, TX 79902, United St...
# 1   4815 Alameda Ave, El Paso, TX 79905, United St...
# 2   10301 Gateway Blvd W, El Paso, TX 79925, Unite...
# 3   1625 Medical Center St Drive, El Paso, TX 7990...
# 4   2001 N Oregon St, El Paso, TX 79902, United St...
# 5   10301 Gateway Blvd W, El Paso, TX 79925, Unite...
# 6   11274 McCombs St, El Paso, TX 79934, United St...
# 7     1740 Curie Dr, El Paso, TX 79902, United States
# 8   2311 N Oregon St Floor 5, El Paso, TX 79902, U...
# 9   5340 El Paso Dr # A, El Paso, TX 79905, United...
# 10  5001 N Piedras St, El Paso, TX 79930, United S...
# 11  1801 N Oregon St Emergency Entrance, 1801 N Or...
# 12  4845 Alameda Ave, El Paso, TX 79905, United St...
# 13  1209 N Cotton St, El Paso, TX 79902, United St...
# 14  4824 Alberta Ave, El Paso, TX 79905, United St...
# 15  4801 Alberta Ave, El Paso, TX 79905, United St...
# 16  1730 Murchison Dr, El Paso, TX 79902, United S...
# 17  5001 El Paso Dr, El Paso, TX 79905, United States
# 18  550 S Mesa Hills Dr C-3, El Paso, TX 79912, Un...
# 19  1810 McRae Blvd A, El Paso, TX 79925, United S...
#
#                        Place_ID Business_Status
# 0   ChIJa3k-QVdY54YRFGGXPE1-NWw     OPERATIONAL
# 1   ChIJg1Eka9Nb54YRtLaD5QRJPKc     OPERATIONAL
# 2   ChIJ59Qbe0xb54YR8eMTD_d19l0     OPERATIONAL
# 3   ChIJQaz3G65Z54YRf7-zW_IcBxY     OPERATIONAL
# 4   ChIJH6gG81lY54YR2FpfF3BrWAI     OPERATIONAL
# 5   ChIJK9zpc0xb54YRH69oaRw1Y4I     OPERATIONAL
# 6   ChIJ5cMTYjJT54YRWVtDHAXm9xk     OPERATIONAL
# 7   ChIJr-8a569Z54YRRI46wx1F1gk     OPERATIONAL
# 8   ChIJiw3N_g5Z54YRs-ZUbzANC5k     OPERATIONAL
# 9   ChIJC8-iys1b54YRjW6VNNARM0M     OPERATIONAL
# 10  ChIJT9ynd7BZ54YRpaSZQxwDkI8     OPERATIONAL
# 11  ChIJ1cToW1dY54YRjmbXWiqiNgU     OPERATIONAL
# 12  ChIJ4zuGd9Nb54YRPTpx12JANe4     OPERATIONAL
# 13  ChIJMTcWWrpZ54YR-jHs6lHlmLw     OPERATIONAL
# 14  ChIJqXNB7AJb54YRVmep-C7I5iQ     OPERATIONAL
# 15  ChIJQ1mFMWtE54YR6B98C5ZmPQc     OPERATIONAL
# 16  ChIJj1YY0rFZ54YRqx8iQgsS1gY     OPERATIONAL
# 17  ChIJ3_KUadNb54YRX0Li3IteRS8     OPERATIONAL
# 18  ChIJX1C_yFtX54YRRofk1NqScMo     OPERATIONAL
# 19  ChIJZY8UKjdb54YR9OW3M-lG6-4     OPERATIONAL

# %%
import requests
import pandas as pd
# Execute Google Places fetch (requires API Key)
google_df = fetch_google_places_data("Clinic OR Medical Center OR Hospital", "Lascruses, NM")
print(f"Google Places Records Retrieved: {len(google_df)}")
# Out:
# Google Places Records Retrieved: 20

# %%
google_df
# Out:
#            Source                                               Name  \
# 0   Google Places                            Memorial Medical Center
# 1   Google Places               MountainView Regional Medical Center
# 2   Google Places                    Three Crosses Regional Hospital
# 3   Google Places    Central Medical Services Of Southern New Mexico
# 4   Google Places            Memorial Family HealthCare - North Main
# 5   Google Places                         MMC Family Medicine Center
# 6   Google Places                           Foothills Medical Center
# 7   Google Places                                   Covenant Clinics
# 8   Google Places      Advanced Care Hospital of Southern New Mexico
# 9   Google Places                                Monte Bello Medical
# 10  Google Places                                Memorial HealthPlex
# 11  Google Places                New Mexico Primary Care Group, P.C.
# 12  Google Places                              Health Care Solutions
# 13  Google Places            Memorial Medical Center- Emergency Room
# 14  Google Places                Desert Springs Medical Center, P.C.
# 15  Google Places            La Clinica de Familia - Central Medical
# 16  Google Places                        Memorial Urgent Care Sonoma
# 17  Google Places   Mountain View Regional Medical Outpatient Center
# 18  Google Places  Memorial Wound Care Center & Outpatient Specia...
# 19  Google Places        MountainView Emergency Center at North Main
#
#                                               Address  \
# 0   2450 S Telshor Blvd, Las Cruces, NM 88011, Uni...
# 1   4311 E Lohman Ave, Las Cruces, NM 88011, Unite...
# 2   2560 Samaritan Dr, Las Cruces, NM 88001, Unite...
# 3   141 Roadrunner Pkwy, Las Cruces, NM 88011, Uni...
# 4   2611 N Main St, Las Cruces, NM 88001, United S...
# 5   2605 Terrace Dr, Las Cruces, NM 88011, United ...
# 6   3530 Foothills Rd Ste N, Las Cruces, NM 88011,...
# 7   3961 E Lohman Ave #34, Las Cruces, NM 88011, U...
# 8   4451 E Lohman Ave, Las Cruces, NM 88011, Unite...
# 9   3851 E Lohman Ave #4, Las Cruces, NM 88011, Un...
# 10  2735 E Northrise Dr, Las Cruces, NM 88011, Uni...
# 11  179 Howard Pl, Las Cruces, NM 88011, United St...
# 12  1680 Calle De Alvarez # B, Las Cruces, NM 8800...
# 13  2450 S Telshor Blvd, Las Cruces, NM 88011, Uni...
# 14  1165 Commerce Dr Suite A, Las Cruces, NM 88011...
# 15  575 S Alameda Blvd, Las Cruces, NM 88005, Unit...
# 16  4672 Sonoma Ranch Blvd Suite A, Las Cruces, NM...
# 17  4301 E Lohman Ave, Las Cruces, NM 88011, Unite...
# 18  2735 E Northrise Dr Suite B, Las Cruces, NM 88...
# 19  2811 N Main St, Las Cruces, NM 88005, United S...
#
#                        Place_ID Business_Status
# 0   ChIJ1Vgpdu4X3oYREsBMd7Tf4iQ     OPERATIONAL
# 1   ChIJP2JLKUw93oYRKIE8UShyqso     OPERATIONAL
# 2   ChIJ47cMIlk93oYRj1nheUYKae8     OPERATIONAL
# 3   ChIJU1mmfmQ93oYR2BgycSqKR94     OPERATIONAL
# 4   ChIJk0-tDwI93oYRAi-P-z0DRdU     OPERATIONAL
# 5   ChIJqbnp4fEX3oYRgQ8ExpLDvpM     OPERATIONAL
# 6   ChIJyyAjyFs93oYRu4Gv-3LUqcM     OPERATIONAL
# 7   ChIJC1rW60893oYRPBcEU-R0bAE     OPERATIONAL
# 8   ChIJB_ScNOs93oYROwqY1Y2XWg4     OPERATIONAL
# 9   ChIJxRkyHYo93oYRQXt4kSucNyk     OPERATIONAL
# 10  ChIJ3dSMUvs83oYRECdZaERR8qY     OPERATIONAL
# 11  ChIJ058d3PEX3oYRKuTHn0N-T3E     OPERATIONAL
# 12  ChIJe-mrJj4W3oYR3bS_VslSy8M     OPERATIONAL
# 13  ChIJye2vEe4X3oYRor-pmRs4e4A     OPERATIONAL
# 14  ChIJ8bKAK9093oYRob7tS-aRjv8     OPERATIONAL
# 15  ChIJPyHB-IY93oYRLQLvPsWDrbk     OPERATIONAL
# 16  ChIJz8aaTcc83oYRfkYM0duEi4Q     OPERATIONAL
# 17  ChIJkZckejA93oYRVG8UXOg8z0U     OPERATIONAL
# 18  ChIJJ3Xyp-Q83oYRVOKlDeftU8o     OPERATIONAL
# 19  ChIJsZt946493oYRXYWzkFGfiiw     OPERATIONAL

# %%
import requests
import time
import pandas as pd

# --- Configuration ---
# IMPORTANT: Replace this with your actual Google Places API Key
#GOOGLE_API_KEY = "YOUR_API_KEY_HERE"
CITY_QUERY = "El Paso, TX"
SEARCH_TERM = "hospital OR clinic OR medical center"
BASE_URL = "https://maps.googleapis.com/maps/api/place/textsearch/json"
MAX_PAGES = 3
ALL_PLACES = []

def fetch_places(query, page_token=None):
    """
    Makes a single request to the Google Places Text Search API.
    Uses next_page_token for pagination.
    """
    params = {
        'query': query,
        'key': GOOGLE_API_KEY,
    }

    if page_token:
        # If a page_token is provided, only the token and key are needed
        params = {
            'pagetoken': page_token,
            'key': GOOGLE_API_KEY,
        }

    try:
        response = requests.get(BASE_URL, params=params)
        response.raise_for_status() # Raise an exception for bad status codes
        return response.json()
    except requests.exceptions.RequestException as e:
        print(f"Error making API request: {e}")
        return None

def get_all_medical_facilities(search_query):
    """
    Executes the search and paginates through results to reach the 60-result limit.
    """
    global ALL_PLACES
    next_page_token = None

    print(f"Starting search for: '{search_query}' in {CITY_QUERY}")

    for page_num in range(1, MAX_PAGES + 1):
        if page_num > 1 and next_page_token is None:
            # Stop if no more pages are indicated
            break

        # --- Mandatory Delay for Pagination ---
        # The API requires a short delay before the next_page_token becomes valid.
        if next_page_token:
            print(f"Waiting 2 seconds for page token to activate (Page {page_num}/3)...")
            time.sleep(2)

        # Fetch data for the current page
        data = fetch_places(search_query, page_token=next_page_token)

        if data and data.get('results'):
            results = data['results']
            print(f"  -> Retrieved {len(results)} results for page {page_num}.")

            # Extract relevant fields and add to the main list
            for place in results:
                place_record = {
                    'Name': place.get('name'),
                    'Address': place.get('formatted_address'),
                    'Place ID': place.get('place_id'),
                    'Rating': place.get('rating'),
                    'Total Reviews': place.get('user_ratings_total'),
                    'Types': ', '.join(place.get('types', []))
                }
                ALL_PLACES.append(place_record)

            # Check for the next page token
            next_page_token = data.get('next_page_token')
            if next_page_token is None and page_num < MAX_PAGES:
                print("No more pages indicated after this page.")
                break # Exit loop if no token is found
        else:
            print(f"No results found or an error occurred on page {page_num}.")
            break

    return pd.DataFrame(ALL_PLACES)

# %%
# --- Execution ---
df_results = get_all_medical_facilities(f"{SEARCH_TERM} in {CITY_QUERY}")
print("\n--- FINAL RESULTS SUMMARY ---")
# Out:
# Starting search for: 'hospital OR clinic OR medical center in El Paso, TX' in El Paso, TX
#   -> Retrieved 20 results for page 1.
# Waiting 2 seconds for page token to activate (Page 2/3)...
#   -> Retrieved 20 results for page 2.
# Waiting 2 seconds for page token to activate (Page 3/3)...
#   -> Retrieved 20 results for page 3.
#
# --- FINAL RESULTS SUMMARY ---

# %%
print(f"Total Unique Medical Facilities Retrieved: {len(df_results)}")
# Out:
# Total Unique Medical Facilities Retrieved: 60

# %%
df_results
# Out:
#                                                  Name  \
# 0                University Medical Center of El Paso
# 1                              Del Sol Medical Center
# 2                           Las Palmas Medical Center
# 3         The Hospitals of Providence Memorial Campus
# 4             The Hospitals of Providence East Campus
# 5           The Hospitals of Providence Sierra Campus
# 6                            Kindred Hospital El Paso
# 7        The Hospitals of Providence Northeast Campus
# 8                         El Paso Children’s Hospital
# 9               Premier Specialty Hospital of El Paso
# 10  Texas Tech University Health Sciences Center E...
# 11  University Medical Center of El Paso Emergency...
# 12             Del Sol Medical Center: Emergency Room
# 13                   Texas Tech Physicians of El Paso
# 14                          El Paso VA Medical Center
# 15               University Medical Center Of El Paso
# 16                             Paisano Medical Center
# 17              Las Palmas Del Sol Healthcare Horizon
# 18   The Hospitals of Providence Transmountain Campus
# 19  University Medical Center of El Paso - Main Ca...
# 20               University Medical Center Of El Paso
# 21                     Montwood Family Medical Center
# 22               William Beaumont Army Medical Center
# 23            Foundation Surgical Hospital of El Paso
# 24                            Hopewell Medical Center
# 25                            Sun City Medical Clinic
# 26                            Franklin Medical Center
# 27                        El Paso Emergency Room East
# 28                          James Watt Medical Center
# 29                 Village Medical - South Mesa Hills
# 30                  Summit Urgent Care - East El Paso
# 31      PAM Health Rehabilitation Hospital of El Paso
# 32                                  UMC - West Clinic
# 33                        SCENIC POINT MEDICAL CENTER
# 34           Las Palmas Medical Center Emergency Room
# 35                               Primary Care El Paso
# 36                               El Paso Primary Care
# 37  UCare Urgent Care Clinics Lee Trevino Dr - El ...
# 38                              United Medical Clinic
# 39      Texas Tech Physicians of El Paso at Kenworthy
# 40                    UMC - East Emergency Department
# 41                                UMC - Ysleta Clinic
# 42                         El Paso Psychiatric Center
# 43               Providence Medical Partners - Sierra
# 44                              Mccombs Medical Plaza
# 45                                                Mch
# 46                                  UMC - East Clinic
# 47    The Hospitals of Providence Horizon City Campus
# 48                            Viscount Medical Center
# 49                   El Paso Behavioral Health System
# 50                              UNITED MEDICAL CLINIC
# 51                      Mt. West Family Health Center
# 52                       Southwest Urgent Care Center
# 53                          University Medical Center
# 54  University Medical Center of El Paso - Ysleta ...
# 55   ER - The Hospitals of Providence - Sierra Campus
# 56  The Hospitals of Providence Emergency Room - E...
# 57           Las Palmas Del Sol Emergency Center West
# 58                      Mt. West Family Health Center
# 59                  Paul L. Foster School of Medicine
#
#                                               Address  \
# 0   4815 Alameda Ave, El Paso, TX 79905, United St...
# 1   10301 Gateway Blvd W, El Paso, TX 79925, Unite...
# 2   1801 N Oregon St, El Paso, TX 79902, United St...
# 3   2001 N Oregon St, El Paso, TX 79902, United St...
# 4   3280 Joe Battle Blvd, El Paso, TX 79938, Unite...
# 5   1625 Medical Center St Drive, El Paso, TX 7990...
# 6     1740 Curie Dr, El Paso, TX 79902, United States
# 7   11274 McCombs St, El Paso, TX 79934, United St...
# 8   4845 Alameda Ave, El Paso, TX 79905, United St...
# 9   2311 N Oregon St Floor 5, El Paso, TX 79902, U...
# 10  5001 El Paso Dr, El Paso, TX 79905, United States
# 11  4815 Alameda Ave, El Paso, TX 79905, United St...
# 12  10301 Gateway Blvd W, El Paso, TX 79925, Unite...
# 13  4801 Alberta Ave, El Paso, TX 79905, United St...
# 14  5001 N Piedras St, El Paso, TX 79930, United S...
# 15                   El Paso, TX 79924, United States
# 16  5340 El Paso Dr # A, El Paso, TX 79905, United...
# 17  13401 Gateway Blvd W, El Paso, TX 79928, Unite...
# 18  2000 Woodrow Bean Transmountain Dr, El Paso, T...
# 19  4824 Alberta Ave, El Paso, TX 79905, United St...
# 20  1209 N Cotton St, El Paso, TX 79902, United St...
# 21  3022 Trawood Dr, El Paso, TX 79936, United States
# 22  18511 Highlander Medics St, Fort Bliss, TX 799...
# 23  1416 George Dieter Dr, El Paso, TX 79936, Unit...
# 24  100 Executive Center Blvd Suite B, El Paso, TX...
# 25  1651 Joe Battle Blvd Suite A & C, El Paso, TX ...
# 26  836 E Redd Rd #7221, El Paso, TX 79912, United...
# 27  3281 Joe Battle Blvd, El Paso, TX 79936, Unite...
# 28    James Watt Dr, El Paso, TX 79936, United States
# 29  550 S Mesa Hills Dr C-3, El Paso, TX 79912, Un...
# 30  1523 N Zaragoza Rd, El Paso, TX 79936, United ...
# 31  1600 E Cliff Dr, El Paso, TX 79902, United States
# 32  6600 N Desert Blvd, El Paso, TX 79912, United ...
# 33  1730 Murchison Dr, El Paso, TX 79902, United S...
# 34  1801 N Oregon St Emergency Entrance, 1801 N Or...
# 35  6000 Northern Pass Dr Ste A100, El Paso, TX 79...
# 36   4545 N Mesa St, El Paso, TX 79912, United States
# 37  1618 Lee Trevino Dr, El Paso, TX 79936, United...
# 38  1810 McRae Blvd A, El Paso, TX 79925, United S...
# 39  9849 Kenworthy St, El Paso, TX 79924, United S...
# 40  1521 Joe Battle Blvd, El Paso, TX 79936, Unite...
# 41  300 S Zaragoza Rd, El Paso, TX 79907, United S...
# 42  4615 Alameda Ave, El Paso, TX 79905, United St...
# 43  1600 Medical Center St #309, El Paso, TX 79902...
# 44                   El Paso, TX 79934, United States
# 45  501599 E Mills Ave, El Paso, TX 79901, United ...
# 46  1521 Joe Battle Blvd, El Paso, TX 79936, Unite...
# 47  13600 Horizon Blvd Suite 240, Horizon City, TX...
# 48  9398 Viscount Blvd Suite 4-C, El Paso, TX 7992...
# 49  1900 Denver Ave, El Paso, TX 79902, United States
# 50     7806 West Dr, El Paso, TX 79915, United States
# 51  1860 Dean Martin Dr # 104, El Paso, TX 79936, ...
# 52   2030 N Mesa St, El Paso, TX 79902, United States
# 53                   El Paso, TX 79907, United States
# 54  300 S Zaragoza Rd, El Paso, TX 79907, United S...
# 55  1625 Medical Center St, El Paso, TX 79902, Uni...
# 56  12101 Edgemere Blvd, El Paso, TX 79938, United...
# 57  1535 N Resler Dr, El Paso, TX 79912, United St...
# 58  6151 Dew Dr #410, El Paso, TX 79912, United St...
# 59  5001 El Paso Dr, El Paso, TX 79905, United States
#
#                        Place ID  Rating  Total Reviews  \
# 0   ChIJg1Eka9Nb54YRtLaD5QRJPKc     3.1          979.0
# 1   ChIJ59Qbe0xb54YR8eMTD_d19l0     3.6         1495.0
# 2   ChIJa3k-QVdY54YRFGGXPE1-NWw     4.0         1027.0
# 3   ChIJH6gG81lY54YR2FpfF3BrWAI     2.7          410.0
# 4   ChIJe5_b9TFE54YRIzUIx_XsuXw     2.1          951.0
# 5   ChIJQaz3G65Z54YRf7-zW_IcBxY     2.7          332.0
# 6   ChIJr-8a569Z54YRRI46wx1F1gk     4.4          414.0
# 7   ChIJ5cMTYjJT54YRWVtDHAXm9xk     3.6          473.0
# 8   ChIJ4zuGd9Nb54YRPTpx12JANe4     3.2          274.0
# 9   ChIJiw3N_g5Z54YRs-ZUbzANC5k     4.1           69.0
# 10  ChIJ3_KUadNb54YRX0Li3IteRS8     4.0           37.0
# 11  ChIJn5LgnNRb54YRoRWUgbGqO8E     2.1           89.0
# 12  ChIJK9zpc0xb54YRH69oaRw1Y4I     3.1           18.0
# 13  ChIJQ1mFMWtE54YR6B98C5ZmPQc     3.9          242.0
# 14  ChIJT9ynd7BZ54YRpaSZQxwDkI8     3.0          227.0
# 15  ChIJv3Yq9j5R54YR2YyW86aRI0E     NaN            NaN
# 16  ChIJC8-iys1b54YRjW6VNNARM0M     4.0          146.0
# 17  ChIJr6d3nGxD54YR3GqBYn3oWmI     2.6          129.0
# 18  ChIJAdR1DTz_3YYRto3ITFSf-7E     2.7          488.0
# 19  ChIJqXNB7AJb54YRVmep-C7I5iQ     NaN            NaN
# 20  ChIJMTcWWrpZ54YR-jHs6lHlmLw     NaN            NaN
# 21  ChIJVSDVG4pE54YRlIvNeMqetu0     1.8          188.0
# 22  ChIJw1V1l0hP54YRJxY2ZamRAfU     2.6          396.0
# 23  ChIJcYjBlHdD54YRn7XbPqqXo3Y     2.8           49.0
# 24  ChIJC1q03G1Z54YR23I2tR6pyUI     4.9           39.0
# 25  ChIJV_ExSPFD54YRa0nfIzHck4k     4.5          726.0
# 26  ChIJfR1bppH43YYR3c55jEVCixE     2.8           86.0
# 27  ChIJ1ZnwjTNE54YROc7NQRXAciQ     4.8         1279.0
# 28  ChIJMVZlISZD54YRkJpKtN4tguA     3.2           13.0
# 29  ChIJX1C_yFtX54YRRofk1NqScMo     4.8          850.0
# 30  ChIJgR4ru3dD54YRTt_Bo1k57m4     4.7         6043.0
# 31  ChIJXf3pWK5Z54YRWhegACi-rAA     4.8          550.0
# 32  ChIJb1DD5Cn_3YYR4I3Ay9UncEk     4.1          274.0
# 33  ChIJj1YY0rFZ54YRqx8iQgsS1gY     3.5            4.0
# 34  ChIJ1cToW1dY54YRjmbXWiqiNgU     4.3          177.0
# 35  ChIJfeiQTFD_3YYRIdPZQPRzmRo     4.5          330.0
# 36  ChIJF4xEyJRZ54YRtAGakwLBqxI     4.9          164.0
# 37  ChIJ0b3V9mlF54YRNC1BOX5sIe0     4.3          303.0
# 38  ChIJZY8UKjdb54YR9OW3M-lG6-4     3.6           23.0
# 39  ChIJKxqbE05R54YRZe8lYghfPBk     3.0           99.0
# 40  ChIJCx0aJ3pD54YRLq370cpFuPk     2.5           35.0
# 41  ChIJB5-KgtRb54YRHaOnEDWgF-g     3.3           94.0
# 42  ChIJ9Qxv89Rb54YRKtyqvtQbB5o     3.0           48.0
# 43  ChIJ8VtbSa5Z54YRLBqJdJqaLY8     2.4            7.0
# 44  ChIJKTIff7pT54YRd3wV51tuspQ     5.0            1.0
# 45  ChIJ1WhX1fhZ54YRWJ7zT5B0LcU     4.0            1.0
# 46  ChIJR_Dbae5D54YRuHXJWXc2EcA     2.8          216.0
# 47  ChIJ2ZVpms1B54YRzcHNmVI72Y4     3.6          485.0
# 48  ChIJC-JAa8Rb54YRH88lHlvnU5U     NaN            NaN
# 49  ChIJT9ynd7BZ54YRFPniuaIiCgU     2.7          402.0
# 50  ChIJs7wYd6dc54YRA0nw6g_AkbA     2.6            5.0
# 51  ChIJYWn282FE54YRROhnR7udpgg     4.1          236.0
# 52  ChIJGa7fm1BY54YRgzqOv-HEEnU     4.8          676.0
# 53  ChIJMeFHBFxD54YR7ccs02S84xg     4.2            5.0
# 54  ChIJgT69lCVD54YRojkLQohqlNQ     5.0            1.0
# 55  ChIJy1diuyRZ54YRgzQcfx7nq6A     2.4           16.0
# 56  ChIJcwnf0klF54YRM7m-8IZAC_4     2.2          157.0
# 57  ChIJIRppjc_43YYRM0ck3wVuCLU     3.1          129.0
# 58  ChIJM0tktN5X54YRNNMOgZdiUo8     3.9          172.0
# 59  ChIJt2Tf-dJb54YReNrp3IXkss4     4.6           37.0
#
#                                                 Types
# 0   hospital, point_of_interest, health, establish...
# 1   hospital, point_of_interest, health, establish...
# 2   hospital, point_of_interest, health, establish...
# 3   hospital, point_of_interest, health, establish...
# 4   hospital, point_of_interest, health, establish...
# 5   hospital, point_of_interest, health, establish...
# 6   hospital, point_of_interest, health, establish...
# 7   hospital, point_of_interest, health, establish...
# 8   hospital, point_of_interest, health, establish...
# 9   hospital, point_of_interest, health, establish...
# 10       university, point_of_interest, establishment
# 11           point_of_interest, health, establishment
# 12           point_of_interest, health, establishment
# 13   point_of_interest, doctor, health, establishment
# 14  hospital, point_of_interest, health, establish...
# 15           point_of_interest, health, establishment
# 16   point_of_interest, doctor, health, establishment
# 17           point_of_interest, health, establishment
# 18  hospital, point_of_interest, health, establish...
# 19           point_of_interest, health, establishment
# 20           health, point_of_interest, establishment
# 21           health, point_of_interest, establishment
# 22  hospital, health, point_of_interest, establish...
# 23  hospital, doctor, health, point_of_interest, e...
# 24           health, point_of_interest, establishment
# 25   doctor, health, point_of_interest, establishment
# 26   doctor, health, point_of_interest, establishment
# 27           health, point_of_interest, establishment
# 28   doctor, health, point_of_interest, establishment
# 29           health, point_of_interest, establishment
# 30   doctor, health, point_of_interest, establishment
# 31  hospital, health, point_of_interest, establish...
# 32  pharmacy, health, store, point_of_interest, es...
# 33  hospital, health, point_of_interest, establish...
# 34           health, point_of_interest, establishment
# 35  hospital, health, point_of_interest, establish...
# 36   doctor, health, point_of_interest, establishment
# 37   doctor, health, point_of_interest, establishment
# 38           health, point_of_interest, establishment
# 39   doctor, health, point_of_interest, establishment
# 40  hospital, health, point_of_interest, establish...
# 41  hospital, health, point_of_interest, establish...
# 42  hospital, health, point_of_interest, establish...
# 43           health, point_of_interest, establishment
# 44                   point_of_interest, establishment
# 45  hospital, health, point_of_interest, establish...
# 46  hospital, doctor, health, point_of_interest, e...
# 47  hospital, health, point_of_interest, establish...
# 48  hospital, health, point_of_interest, establish...
# 49           health, point_of_interest, establishment
# 50           health, point_of_interest, establishment
# 51   doctor, health, point_of_interest, establishment
# 52           health, point_of_interest, establishment
# 53                   point_of_interest, establishment
# 54           health, point_of_interest, establishment
# 55           health, point_of_interest, establishment
# 56           health, point_of_interest, establishment
# 57           health, point_of_interest, establishment
# 58  hospital, health, point_of_interest, establish...
# 59       university, point_of_interest, establishment

# %%
import requests
import pandas as pd

# --- Configuration ---
CITY = "EL PASO"
STATE = "TX"
BASE_URL = "https://npiregistry.cms.hhs.gov/api/"
# Maximum results per request (set to max)
LIMIT = 200
# The API allows a maximum skip of 1000, allowing retrieval of up to 1200 records.
MAX_RECORDS = 1200

# TAXONOMY_CODE is now commented out for a broad search.
# TAXONOMY_CODE = "261Q00000X OR 282N00000X"

def fetch_npi_data(entity_type, search_limit, search_skip):
    """Fetches NPI records for a specific entity type (NPI-1 or NPI-2)."""
    params = {
        'version': '2.1',
        'city': CITY,
        'state': STATE,
        'enumeration_type': entity_type,
        'limit': search_limit,
        'skip': search_skip,
        # Taxonomy is excluded here to maximize results
    }

    response = requests.get(BASE_URL, params=params)
    if response.status_code == 200:
        return response.json()
    else:
        print(f"Error fetching data for {entity_type}: HTTP {response.status_code}")
        return None

def parse_npi_results(data, entity_type):
    """Parses the JSON response into a list of dictionaries."""
    records = []

    for item in data.get('results', []):
        basic = item.get('basic', {})
        address = item.get('addresses', [{}])[0]
        taxonomy = item.get('taxonomies', [{}]) # Get the list of taxonomies

        # Determine Name based on entity type
        if entity_type == 'NPI-2': # Organization (Clinic/Hospital)
            full_name = basic.get('organization_name', 'N/A')

        else: # NPI-1 (Individual Doctor)
            first = basic.get('first_name', '')
            last = basic.get('last_name', '')
            credential = basic.get('credential', '')
            full_name = f"{first} {last}, {credential}".strip()

        record = {
            'NPI_Type': entity_type,
            'Name': full_name,
            'Address_Line_1': address.get('address_1', 'N/A'),
            'City': address.get('city', 'N/A'),
            'State': address.get('state', 'N/A'),
            'NPI_Number': item.get('number', 'N/A'),
            # Use the primary taxonomy description
            'Primary_Taxonomy': taxonomy[0].get('desc', 'N/A') if taxonomy else 'N/A',
            'Title': basic.get('sole_proprietor') if entity_type == 'NPI-1' else 'Organization'
        }
        records.append(record)
    return records

def get_all_records(entity_type):
    """Paginates through NPI results using the 'skip' parameter."""
    all_data = []
    total_found = 0
    skip = 0

    print(f"\n--- Searching for {entity_type} providers (Broad Search) ---")

    while True:
        data = fetch_npi_data(entity_type, LIMIT, skip)

        if data is None:
            break

        results = data.get('results', [])
        current_count = len(results)
        total_found += current_count

        print(f"  -> Retrieved {current_count} records. Total found: {total_found}")

        if not results:
            break

        all_data.extend(parse_npi_results(data, entity_type))

        # Stop condition checks if we've hit the record limit or the API's skip limit
        if current_count < LIMIT or skip >= MAX_RECORDS - LIMIT:
            break

        skip += LIMIT

    return all_data

# %%
# --- Execution ---
# 1. Fetch Organization (Hospitals/Clinics/Medical Groups)
facility_records = get_all_records('NPI-2')
df_facilities = pd.DataFrame(facility_records)
# Out:
# --- Searching for NPI-2 providers (Broad Search) ---
#   -> Retrieved 200 records. Total found: 200
#   -> Retrieved 200 records. Total found: 400
#   -> Retrieved 200 records. Total found: 600
#   -> Retrieved 200 records. Total found: 800
#   -> Retrieved 200 records. Total found: 1000
#   -> Retrieved 200 records. Total found: 1200

# %%
df_facilities
# Out:
#      NPI_Type                                  Name           Address_Line_1  \
# 0       NPI-2             1188 YARBROUGH DRIVE PLLC  10510 MONTWOOD DR STE B
# 1       NPI-2                   12900 EASTLAKE PLLC  10510 MONTWOOD DR STE B
# 2       NPI-2                   13650 EASTLAKE PLLC  10510 MONTWOOD DR STE B
# 3       NPI-2               13660 HORIZON BLVD PLLC  10510 MONTWOOD DR STE B
# 4       NPI-2                 1550 ZARAGOZA RD PLLC  10510 MONTWOOD DR STE B
# ...       ...                                   ...                      ...
# 1195    NPI-2                 EL PASO OPTICAL, P.C.         4724 MONTANA AVE
# 1196    NPI-2  EL PASO ORAL & FACIAL SURGEONS, PLLC      4447 N CENTRAL EXPY
# 1197    NPI-2     EL PASO ORAL SURGERY CENTER, PLLC       6421 SARATOGA BLVD
# 1198    NPI-2             EL PASO ORAL SURGERY PLLC   2201 CIVIC CIR STE 600
# 1199    NPI-2        EL PASO ORTHOPAEDIC ASSOCIATES              5823 N MESA
#
#                 City State  NPI_Number  \
# 0            EL PASO    TX  1821886854
# 1            EL PASO    TX  1376314096
# 2            EL PASO    TX  1427829589
# 3            EL PASO    TX  1174311195
# 4            EL PASO    TX  1124816152
# ...              ...   ...         ...
# 1195         EL PASO    TX  1609134949
# 1196          DALLAS    TX  1326423468
# 1197  CORPUS CHRISTI    TX  1699133801
# 1198        AMARILLO    TX  1700773066
# 1199         EL PASO    TX  1013081207
#
#                              Primary_Taxonomy         Title
# 0                       Clinic/Center, Dental  Organization
# 1                   Dentist, General Practice  Organization
# 2                   Dentist, General Practice  Organization
# 3                       Clinic/Center, Dental  Organization
# 4                       Clinic/Center, Dental  Organization
# ...                                       ...           ...
# 1195                              Optometrist  Organization
# 1196  Dentist, Oral and Maxillofacial Surgery  Organization
# 1197  Dentist, Oral and Maxillofacial Surgery  Organization
# 1198  Dentist, Oral and Maxillofacial Surgery  Organization
# 1199        Orthopaedic Surgery, Hand Surgery  Organization
#
# [1200 rows x 8 columns]

# %%
# 2. Fetch Individual Doctors (All individual providers)
doctor_records = get_all_records('NPI-1')
df_doctors = pd.DataFrame(doctor_records)
# Out:
# --- Searching for NPI-1 providers (Broad Search) ---
#   -> Retrieved 200 records. Total found: 200
#   -> Retrieved 200 records. Total found: 400
#   -> Retrieved 200 records. Total found: 600
#   -> Retrieved 200 records. Total found: 800
#   -> Retrieved 200 records. Total found: 1000
#   -> Retrieved 200 records. Total found: 1200

# %%
# # 3. Combine and Save
final_df = pd.concat([df_facilities, df_doctors], ignore_index=True)

print("\n--- FINAL NPI RESULTS SUMMARY ---")
print(f"Total Combined Records Retrieved: {len(final_df)}")
# Out:
# --- FINAL NPI RESULTS SUMMARY ---
# Total Combined Records Retrieved: 2400

# %%
final_df
# Out:
#      NPI_Type                         Name              Address_Line_1  \
# 0       NPI-2    1188 YARBROUGH DRIVE PLLC     10510 MONTWOOD DR STE B
# 1       NPI-2          12900 EASTLAKE PLLC     10510 MONTWOOD DR STE B
# 2       NPI-2          13650 EASTLAKE PLLC     10510 MONTWOOD DR STE B
# 3       NPI-2      13660 HORIZON BLVD PLLC     10510 MONTWOOD DR STE B
# 4       NPI-2        1550 ZARAGOZA RD PLLC     10510 MONTWOOD DR STE B
# ...       ...                          ...                         ...
# 2395    NPI-1          CHAD BERRYMAN, M.D.  1 UNIVERSITY OF NEW MEXICO
# 2396    NPI-1              SHELBY BERTRAM,                 1408 8TH ST
# 2397    NPI-1          DAVID BERUMEN, COTA      11169 SEAN HAGGERTY DR
# 2398    NPI-1  EDUARDO BERUMEN, RN.  FNP-C           844 HEMPSTEAD DR.
# 2399    NPI-1        KENNETH BERUMEN, M.D.        6112 LAGUNA VISTA DR
#
#              City State  NPI_Number                Primary_Taxonomy  \
# 0         EL PASO    TX  1821886854           Clinic/Center, Dental
# 1         EL PASO    TX  1376314096       Dentist, General Practice
# 2         EL PASO    TX  1427829589       Dentist, General Practice
# 3         EL PASO    TX  1174311195           Clinic/Center, Dental
# 4         EL PASO    TX  1124816152           Clinic/Center, Dental
# ...           ...   ...         ...                             ...
# 2395  ALBUQUERQUE    NM  1578856233              Emergency Medicine
# 2396   ALAMOGORDO    NM  1740084367             Behavior Technician
# 2397      EL PASO    TX  1396226171  Occupational Therapy Assistant
# 2398      EL PASO    TX  1609171768      Nurse Practitioner, Family
# 2399      EL PASO    TX  1588661243              Emergency Medicine
#
#              Title
# 0     Organization
# 1     Organization
# 2     Organization
# 3     Organization
# 4     Organization
# ...            ...
# 2395            NO
# 2396            NO
# 2397            NO
# 2398           YES
# 2399            NO
#
# [2400 rows x 8 columns]

# %%
print(final_df.head())
# final_df.to_csv('el_paso_broad_npi_directory.csv', index=False)

# %%
import requests
import pandas as pd
import time

# --- Configuration ---
# List of El Paso, TX ZIP codes (use a comprehensive list for max coverage)
EL_PASO_ZIPS = [
    "79901", "79902", "79903", "79904", "79905", "79906", "79907",
    "79908", "79910", "79911", "79912", "79913", "79914", "79915",
    "79916", "79917", "79918", "79920", "79922", "79923", "79924",
    "79925", "79926", "79927", "79928", "79929", "79930", "79931",
    "79932", "79934", "79935", "79936", "79937", "79938", "79940",
    "79941", "79942", "79943", "79944", "79945", "79946", "79947",
    "79948", "79949", "79950", "79951", "79952", "79953", "79954",
    "79955", "79958", "79960", "79961", "79968", "79976", "79978",
    "79980", "79990", "79995", "79996", "79997", "79998", "79999"
]
BASE_URL = "https://npiregistry.cms.hhs.gov/api/"
LIMIT = 200  # Max records per request
MAX_SKIP = 1000 # Max skip allowed by NPI API (allowing 1200 total records per ZIP)

def fetch_npi_data(zip_code, entity_type, search_limit, search_skip):
    """Fetches NPI records using ZIP code as the primary filter."""
    params = {
        'version': '2.1',
        'postal_code': zip_code,
        'enumeration_type': entity_type,
        'limit': search_limit,
        'skip': search_skip,
    }

    response = requests.get(BASE_URL, params=params)
    if response.status_code == 200:
        return response.json()
    else:
        print(f"Error fetching data for {entity_type} in {zip_code}: HTTP {response.status_code}")
        return None

# Reuse the existing parse_npi_results function from the previous step (not repeated here)

def get_all_records_by_zip(zip_code, entity_type):
    """Paginates through NPI results for a single ZIP code."""
    all_data = []
    total_found = 0
    skip = 0

    print(f"\n--- Searching for {entity_type} in ZIP {zip_code} ---")

    while True:
        data = fetch_npi_data(zip_code, entity_type, LIMIT, skip)

        if data is None:
            break

        results = data.get('results', [])
        current_count = len(results)
        total_found += current_count

        print(f"  -> Retrieved {current_count} records. Total found: {total_found}")

        if not results:
            break

        # Assume parse_npi_results is available here
        # all_data.extend(parse_npi_results(data, entity_type))

        # Stop condition: reached end of results or NPI API skip limit
        if current_count < LIMIT or skip >= MAX_SKIP:
            break

        skip += LIMIT

    return all_data

# %%
def run_comprehensive_search():
    """Main function to loop through all ZIP codes and combine results."""
    all_combined_records = []

    for zip_code in EL_PASO_ZIPS:
        # Fetch Type 1 (Doctors)
        doctor_records = get_all_records_by_zip(zip_code, 'NPI-1')
        all_combined_records.extend(doctor_records)

        # Fetch Type 2 (Hospitals/Clinics)
        facility_records = get_all_records_by_zip(zip_code, 'NPI-2')
        all_combined_records.extend(facility_records)

        # A small delay is courteous when performing many searches
        time.sleep(0.5)

    # Convert to DataFrame for easy manipulation
    final_df = pd.DataFrame(all_combined_records)

    # Use pandas to drop duplicates based on the NPI_Number, as this is unique
    #final_df_deduped = final_df.drop_duplicates(subset=['NPI_Number'])

    return final_df

# %%
final_df
# Out:
#      NPI_Type                         Name              Address_Line_1  \
# 0       NPI-2    1188 YARBROUGH DRIVE PLLC     10510 MONTWOOD DR STE B
# 1       NPI-2          12900 EASTLAKE PLLC     10510 MONTWOOD DR STE B
# 2       NPI-2          13650 EASTLAKE PLLC     10510 MONTWOOD DR STE B
# 3       NPI-2      13660 HORIZON BLVD PLLC     10510 MONTWOOD DR STE B
# 4       NPI-2        1550 ZARAGOZA RD PLLC     10510 MONTWOOD DR STE B
# ...       ...                          ...                         ...
# 2395    NPI-1          CHAD BERRYMAN, M.D.  1 UNIVERSITY OF NEW MEXICO
# 2396    NPI-1              SHELBY BERTRAM,                 1408 8TH ST
# 2397    NPI-1          DAVID BERUMEN, COTA      11169 SEAN HAGGERTY DR
# 2398    NPI-1  EDUARDO BERUMEN, RN.  FNP-C           844 HEMPSTEAD DR.
# 2399    NPI-1        KENNETH BERUMEN, M.D.        6112 LAGUNA VISTA DR
#
#              City State  NPI_Number                Primary_Taxonomy  \
# 0         EL PASO    TX  1821886854           Clinic/Center, Dental
# 1         EL PASO    TX  1376314096       Dentist, General Practice
# 2         EL PASO    TX  1427829589       Dentist, General Practice
# 3         EL PASO    TX  1174311195           Clinic/Center, Dental
# 4         EL PASO    TX  1124816152           Clinic/Center, Dental
# ...           ...   ...         ...                             ...
# 2395  ALBUQUERQUE    NM  1578856233              Emergency Medicine
# 2396   ALAMOGORDO    NM  1740084367             Behavior Technician
# 2397      EL PASO    TX  1396226171  Occupational Therapy Assistant
# 2398      EL PASO    TX  1609171768      Nurse Practitioner, Family
# 2399      EL PASO    TX  1588661243              Emergency Medicine
#
#              Title
# 0     Organization
# 1     Organization
# 2     Organization
# 3     Organization
# 4     Organization
# ...            ...
# 2395            NO
# 2396            NO
# 2397            NO
# 2398           YES
# 2399            NO
#
# [2400 rows x 8 columns]

# %%
len(final_df)
# Out:
# 2400

# %%
# --- Execution ---
final_directory = run_comprehensive_search()
# Out:
# --- Searching for NPI-1 in ZIP 79901 ---
#   -> Retrieved 200 records. Total found: 200
#   -> Retrieved 200 records. Total found: 400
#   -> Retrieved 200 records. Total found: 600
#   -> Retrieved 200 records. Total found: 800
#   -> Retrieved 153 records. Total found: 953
#
# --- Searching for NPI-2 in ZIP 79901 ---
#   -> Retrieved 84 records. Total found: 84
#
# --- Searching for NPI-1 in ZIP 79902 ---
#   -> Retrieved 200 records. Total found: 200
#   -> Retrieved 200 records. Total found: 400
#   -> Retrieved 200 records. Total found: 600
#   -> Retrieved 200 records. Total found: 800
#   -> Retrieved 200 records. Total found: 1000
#   -> Retrieved 200 records. Total found: 1200
#
# --- Searching for NPI-2 in ZIP 79902 ---
#   -> Retrieved 200 records. Total found: 200
#   -> Retrieved 200 records. Total found: 400
#   -> Retrieved 200 records. Total found: 600
#   -> Retrieved 152 records. Total found: 752
#
# --- Searching for NPI-1 in ZIP 79903 ---
#   -> Retrieved 200 records. Total found: 200
#   -> Retrieved 104 records. Total found: 304
#
# --- Searching for NPI-2 in ZIP 79903 ---
#   -> Retrieved 171 records. Total found: 171
#
# --- Searching for NPI-1 in ZIP 79904 ---
#   -> Retrieved 200 records. Total found: 200
#   -> Retrieved 37 records. Total found: 237
#
# --- Searching for NPI-2 in ZIP 79904 ---
#   -> Retrieved 72 records. Total found: 72
#
# --- Searching for NPI-1 in ZIP 79905 ---
#   -> Retrieved 200 records. Total found: 200
#   -> Retrieved 200 records. Total found: 400
#   -> Retrieved 200 records. Total found: 600
#   -> Retrieved 200 records. Total found: 800
#   -> Retrieved 200 records. Total found: 1000
#   -> Retrieved 200 records. Total found: 1200
#
# --- Searching for NPI-2 in ZIP 79905 ---
#   -> Retrieved 200 records. Total found: 200
#   -> Retrieved 76 records. Total found: 276
#
# --- Searching for NPI-1 in ZIP 79906 ---
#   -> Retrieved 200 records. Total found: 200
#   -> Retrieved 200 records. Total found: 400
#   -> Retrieved 104 records. Total found: 504
#
# --- Searching for NPI-2 in ZIP 79906 ---
#   -> Retrieved 15 records. Total found: 15
#
# --- Searching for NPI-1 in ZIP 79907 ---
#   -> Retrieved 200 records. Total found: 200
#   -> Retrieved 77 records. Total found: 277
#
# --- Searching for NPI-2 in ZIP 79907 ---
#   -> Retrieved 109 records. Total found: 109
#
# --- Searching for NPI-1 in ZIP 79908 ---
#   -> Retrieved 39 records. Total found: 39
#
# --- Searching for NPI-2 in ZIP 79908 ---
#   -> Retrieved 2 records. Total found: 2
#
# --- Searching for NPI-1 in ZIP 79910 ---
#   -> Retrieved 0 records. Total found: 0
#
# --- Searching for NPI-2 in ZIP 79910 ---
#   -> Retrieved 0 records. Total found: 0
#
# --- Searching for NPI-1 in ZIP 79911 ---
#   -> Retrieved 200 records. Total found: 200
#   -> Retrieved 123 records. Total found: 323
#
# --- Searching for NPI-2 in ZIP 79911 ---
#   -> Retrieved 76 records. Total found: 76
#
# --- Searching for NPI-1 in ZIP 79912 ---
#   -> Retrieved 200 records. Total found: 200
#   -> Retrieved 200 records. Total found: 400
#   -> Retrieved 200 records. Total found: 600
#   -> Retrieved 200 records. Total found: 800
#   -> Retrieved 200 records. Total found: 1000
#   -> Retrieved 200 records. Total found: 1200
#
# --- Searching for NPI-2 in ZIP 79912 ---
#   -> Retrieved 200 records. Total found: 200
#   -> Retrieved 200 records. Total found: 400
#   -> Retrieved 200 records. Total found: 600
#   -> Retrieved 53 records. Total found: 653
#
# --- Searching for NPI-1 in ZIP 79913 ---
#   -> Retrieved 69 records. Total found: 69
#
# --- Searching for NPI-2 in ZIP 79913 ---
#   -> Retrieved 96 records. Total found: 96
#
# --- Searching for NPI-1 in ZIP 79914 ---
#   -> Retrieved 4 records. Total found: 4
#
# --- Searching for NPI-2 in ZIP 79914 ---
#   -> Retrieved 1 records. Total found: 1
#
# --- Searching for NPI-1 in ZIP 79915 ---
#   -> Retrieved 200 records. Total found: 200
#   -> Retrieved 132 records. Total found: 332
#
# --- Searching for NPI-2 in ZIP 79915 ---
#   -> Retrieved 100 records. Total found: 100
#
# --- Searching for NPI-1 in ZIP 79916 ---
#   -> Retrieved 76 records. Total found: 76
#
# --- Searching for NPI-2 in ZIP 79916 ---
#   -> Retrieved 4 records. Total found: 4
#
# --- Searching for NPI-1 in ZIP 79917 ---
#   -> Retrieved 4 records. Total found: 4
#
# --- Searching for NPI-2 in ZIP 79917 ---
#   -> Retrieved 5 records. Total found: 5
#
# --- Searching for NPI-1 in ZIP 79918 ---
#   -> Retrieved 112 records. Total found: 112
#
# --- Searching for NPI-2 in ZIP 79918 ---
#   -> Retrieved 4 records. Total found: 4
#
# --- Searching for NPI-1 in ZIP 79920 ---
#   -> Retrieved 200 records. Total found: 200
#   -> Retrieved 200 records. Total found: 400
#   -> Retrieved 89 records. Total found: 489
#
# --- Searching for NPI-2 in ZIP 79920 ---
#   -> Retrieved 28 records. Total found: 28
#
# --- Searching for NPI-1 in ZIP 79922 ---
#   -> Retrieved 149 records. Total found: 149
#
# --- Searching for NPI-2 in ZIP 79922 ---
#   -> Retrieved 39 records. Total found: 39
#
# --- Searching for NPI-1 in ZIP 79923 ---
#   -> Retrieved 31 records. Total found: 31
#
# --- Searching for NPI-2 in ZIP 79923 ---
#   -> Retrieved 8 records. Total found: 8
#
# --- Searching for NPI-1 in ZIP 79924 ---
#   -> Retrieved 200 records. Total found: 200
#   -> Retrieved 200 records. Total found: 400
#   -> Retrieved 63 records. Total found: 463
#
# --- Searching for NPI-2 in ZIP 79924 ---
#   -> Retrieved 126 records. Total found: 126
#
# --- Searching for NPI-1 in ZIP 79925 ---
#   -> Retrieved 200 records. Total found: 200
#   -> Retrieved 200 records. Total found: 400
#   -> Retrieved 200 records. Total found: 600
#   -> Retrieved 200 records. Total found: 800
#   -> Retrieved 200 records. Total found: 1000
#   -> Retrieved 200 records. Total found: 1200
#
# --- Searching for NPI-2 in ZIP 79925 ---
#   -> Retrieved 200 records. Total found: 200
#   -> Retrieved 200 records. Total found: 400
#   -> Retrieved 144 records. Total found: 544
#
# --- Searching for NPI-1 in ZIP 79926 ---
#   -> Retrieved 4 records. Total found: 4
#
# --- Searching for NPI-2 in ZIP 79926 ---
#   -> Retrieved 12 records. Total found: 12
#
# --- Searching for NPI-1 in ZIP 79927 ---
#   -> Retrieved 152 records. Total found: 152
#
# --- Searching for NPI-2 in ZIP 79927 ---
#   -> Retrieved 64 records. Total found: 64
#
# --- Searching for NPI-1 in ZIP 79928 ---
#   -> Retrieved 200 records. Total found: 200
#   -> Retrieved 200 records. Total found: 400
#   -> Retrieved 115 records. Total found: 515
#
# --- Searching for NPI-2 in ZIP 79928 ---
#   -> Retrieved 129 records. Total found: 129
#
# --- Searching for NPI-1 in ZIP 79929 ---
#   -> Retrieved 5 records. Total found: 5
#
# --- Searching for NPI-2 in ZIP 79929 ---
#   -> Retrieved 3 records. Total found: 3
#
# --- Searching for NPI-1 in ZIP 79930 ---
#   -> Retrieved 200 records. Total found: 200
#   -> Retrieved 200 records. Total found: 400
#   -> Retrieved 98 records. Total found: 498
#
# --- Searching for NPI-2 in ZIP 79930 ---
#   -> Retrieved 50 records. Total found: 50
#
# --- Searching for NPI-1 in ZIP 79931 ---
#   -> Retrieved 2 records. Total found: 2
#
# --- Searching for NPI-2 in ZIP 79931 ---
#   -> Retrieved 1 records. Total found: 1
#
# --- Searching for NPI-1 in ZIP 79932 ---
#   -> Retrieved 200 records. Total found: 200
#   -> Retrieved 148 records. Total found: 348
#
# --- Searching for NPI-2 in ZIP 79932 ---
#   -> Retrieved 107 records. Total found: 107
#
# --- Searching for NPI-1 in ZIP 79934 ---
#   -> Retrieved 200 records. Total found: 200
#   -> Retrieved 74 records. Total found: 274
#
# --- Searching for NPI-2 in ZIP 79934 ---
#   -> Retrieved 45 records. Total found: 45
#
# --- Searching for NPI-1 in ZIP 79935 ---
#   -> Retrieved 200 records. Total found: 200
#   -> Retrieved 200 records. Total found: 400
#   -> Retrieved 94 records. Total found: 494
#
# --- Searching for NPI-2 in ZIP 79935 ---
#   -> Retrieved 200 records. Total found: 200
#   -> Retrieved 38 records. Total found: 238
#
# --- Searching for NPI-1 in ZIP 79936 ---
#   -> Retrieved 200 records. Total found: 200
#   -> Retrieved 200 records. Total found: 400
#   -> Retrieved 200 records. Total found: 600
#   -> Retrieved 200 records. Total found: 800
#   -> Retrieved 200 records. Total found: 1000
#   -> Retrieved 200 records. Total found: 1200
#
# --- Searching for NPI-2 in ZIP 79936 ---
#   -> Retrieved 200 records. Total found: 200
#   -> Retrieved 200 records. Total found: 400
#   -> Retrieved 200 records. Total found: 600
#   -> Retrieved 88 records. Total found: 688
#
# --- Searching for NPI-1 in ZIP 79937 ---
#   -> Retrieved 12 records. Total found: 12
#
# --- Searching for NPI-2 in ZIP 79937 ---
#   -> Retrieved 9 records. Total found: 9
#
# --- Searching for NPI-1 in ZIP 79938 ---
#   -> Retrieved 200 records. Total found: 200
#   -> Retrieved 200 records. Total found: 400
#   -> Retrieved 200 records. Total found: 600
#   -> Retrieved 200 records. Total found: 800
#   -> Retrieved 33 records. Total found: 833
#
# --- Searching for NPI-2 in ZIP 79938 ---
#   -> Retrieved 200 records. Total found: 200
#   -> Retrieved 29 records. Total found: 229
#
# --- Searching for NPI-1 in ZIP 79940 ---
#   -> Retrieved 1 records. Total found: 1
#
# --- Searching for NPI-2 in ZIP 79940 ---
#   -> Retrieved 1 records. Total found: 1
#
# --- Searching for NPI-1 in ZIP 79941 ---
#   -> Retrieved 0 records. Total found: 0
#
# --- Searching for NPI-2 in ZIP 79941 ---
#   -> Retrieved 1 records. Total found: 1
#
# --- Searching for NPI-1 in ZIP 79942 ---
#   -> Retrieved 0 records. Total found: 0
#
# --- Searching for NPI-2 in ZIP 79942 ---
#   -> Retrieved 1 records. Total found: 1
#
# --- Searching for NPI-1 in ZIP 79943 ---
#   -> Retrieved 0 records. Total found: 0
#
# --- Searching for NPI-2 in ZIP 79943 ---
#   -> Retrieved 0 records. Total found: 0
#
# --- Searching for NPI-1 in ZIP 79944 ---
#   -> Retrieved 1 records. Total found: 1
#
# --- Searching for NPI-2 in ZIP 79944 ---
#   -> Retrieved 0 records. Total found: 0
#
# --- Searching for NPI-1 in ZIP 79945 ---
#   -> Retrieved 0 records. Total found: 0
#
# --- Searching for NPI-2 in ZIP 79945 ---
#   -> Retrieved 0 records. Total found: 0
#
# --- Searching for NPI-1 in ZIP 79946 ---
#   -> Retrieved 0 records. Total found: 0
#
# --- Searching for NPI-2 in ZIP 79946 ---
#   -> Retrieved 0 records. Total found: 0
#
# --- Searching for NPI-1 in ZIP 79947 ---
#   -> Retrieved 0 records. Total found: 0
#
# --- Searching for NPI-2 in ZIP 79947 ---
#   -> Retrieved 0 records. Total found: 0
#
# --- Searching for NPI-1 in ZIP 79948 ---
#   -> Retrieved 0 records. Total found: 0
#
# --- Searching for NPI-2 in ZIP 79948 ---
#   -> Retrieved 0 records. Total found: 0
#
# --- Searching for NPI-1 in ZIP 79949 ---
#   -> Retrieved 0 records. Total found: 0
#
# --- Searching for NPI-2 in ZIP 79949 ---
#   -> Retrieved 1 records. Total found: 1
#
# --- Searching for NPI-1 in ZIP 79950 ---
#   -> Retrieved 0 records. Total found: 0
#
# --- Searching for NPI-2 in ZIP 79950 ---
#   -> Retrieved 0 records. Total found: 0
#
# --- Searching for NPI-1 in ZIP 79951 ---
#   -> Retrieved 0 records. Total found: 0
#
# --- Searching for NPI-2 in ZIP 79951 ---
#   -> Retrieved 5 records. Total found: 5
#
# --- Searching for NPI-1 in ZIP 79952 ---
#   -> Retrieved 1 records. Total found: 1
#
# --- Searching for NPI-2 in ZIP 79952 ---
#   -> Retrieved 0 records. Total found: 0
#
# --- Searching for NPI-1 in ZIP 79953 ---
#   -> Retrieved 0 records. Total found: 0
#
# --- Searching for NPI-2 in ZIP 79953 ---
#   -> Retrieved 0 records. Total found: 0
#
# --- Searching for NPI-1 in ZIP 79954 ---
#   -> Retrieved 1 records. Total found: 1
#
# --- Searching for NPI-2 in ZIP 79954 ---
#   -> Retrieved 0 records. Total found: 0
#
# --- Searching for NPI-1 in ZIP 79955 ---
#   -> Retrieved 0 records. Total found: 0
#
# --- Searching for NPI-2 in ZIP 79955 ---
#   -> Retrieved 0 records. Total found: 0
#
# --- Searching for NPI-1 in ZIP 79958 ---
#   -> Retrieved 0 records. Total found: 0
#
# --- Searching for NPI-2 in ZIP 79958 ---
#   -> Retrieved 0 records. Total found: 0
#
# --- Searching for NPI-1 in ZIP 79960 ---
#   -> Retrieved 0 records. Total found: 0
#
# --- Searching for NPI-2 in ZIP 79960 ---
#   -> Retrieved 0 records. Total found: 0
#
# --- Searching for NPI-1 in ZIP 79961 ---
#   -> Retrieved 0 records. Total found: 0
#
# --- Searching for NPI-2 in ZIP 79961 ---
#   -> Retrieved 0 records. Total found: 0
#
# --- Searching for NPI-1 in ZIP 79968 ---
#   -> Retrieved 23 records. Total found: 23
#
# --- Searching for NPI-2 in ZIP 79968 ---
#   -> Retrieved 2 records. Total found: 2
#
# --- Searching for NPI-1 in ZIP 79976 ---
#   -> Retrieved 0 records. Total found: 0
#
# --- Searching for NPI-2 in ZIP 79976 ---
#   -> Retrieved 0 records. Total found: 0
#
# --- Searching for NPI-1 in ZIP 79978 ---
#   -> Retrieved 0 records. Total found: 0
#
# --- Searching for NPI-2 in ZIP 79978 ---
#   -> Retrieved 0 records. Total found: 0
#
# --- Searching for NPI-1 in ZIP 79980 ---
#   -> Retrieved 0 records. Total found: 0
#
# --- Searching for NPI-2 in ZIP 79980 ---
#   -> Retrieved 0 records. Total found: 0
#
# --- Searching for NPI-1 in ZIP 79990 ---
#   -> Retrieved 0 records. Total found: 0
#
# --- Searching for NPI-2 in ZIP 79990 ---
#   -> Retrieved 0 records. Total found: 0
#
# --- Searching for NPI-1 in ZIP 79995 ---
#   -> Retrieved 91 records. Total found: 91
#
# --- Searching for NPI-2 in ZIP 79995 ---
#   -> Retrieved 33 records. Total found: 33
#
# --- Searching for NPI-1 in ZIP 79996 ---
#   -> Retrieved 44 records. Total found: 44
#
# --- Searching for NPI-2 in ZIP 79996 ---
#   -> Retrieved 17 records. Total found: 17
#
# --- Searching for NPI-1 in ZIP 79997 ---
#   -> Retrieved 14 records. Total found: 14
#
# --- Searching for NPI-2 in ZIP 79997 ---
#   -> Retrieved 16 records. Total found: 16
#
# --- Searching for NPI-1 in ZIP 79998 ---
#   -> Retrieved 0 records. Total found: 0
#
# --- Searching for NPI-2 in ZIP 79998 ---
#   -> Retrieved 0 records. Total found: 0
#
# --- Searching for NPI-1 in ZIP 79999 ---
#   -> Retrieved 0 records. Total found: 0
#
# --- Searching for NPI-2 in ZIP 79999 ---
#   -> Retrieved 0 records. Total found: 0

# %%
print(f"\n✅ Total unique providers found across all ZIP codes: {len(final_directory)}")
# final_directory.to_csv('el_paso_comprehensive_npi_directory.csv', index=False)
# Out:
# ✅ Total unique providers found across all ZIP codes: 0

# %%
final_directory
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
import requests
import pandas as pd
import time

# --- Configuration ---
# Comprehensive list of El Paso, TX ZIP codes for maximum coverage
EL_PASO_ZIPS = [
    "79901", "79902", "79903", "79904", "79905", "79906", "79907",
    "79908", "79910", "79911", "79912", "79913", "79914", "79915",
    "79916", "79917", "79918", "79920", "79922", "79923", "79924",
    "79925", "79926", "79927", "79928", "79929", "79930", "79931",
    "79932", "79934", "79935", "79936", "79937", "79938", "79940",
    "79941", "79942", "79943", "79944", "79945", "79946", "79947",
    "79948", "79949", "79950", "79951", "79952", "79953", "79954",
    "79955", "79958", "79960", "79961", "79968", "79976", "79978",
    "79980", "79990", "79995", "79996", "79997", "79998", "79999"
]
BASE_URL = "https://npiregistry.cms.hhs.gov/api/"
LIMIT = 200  # Max records per request
MAX_SKIP = 1000 # Max skip allowed by NPI API (search stops after 1200 records per ZIP/type)

# --- NPI API COMMUNICATION FUNCTIONS ---

def fetch_npi_data(zip_code, entity_type, search_limit, search_skip):
    """Makes a single paginated request to the NPI API."""
    params = {
        'version': '2.1',
        'postal_code': zip_code,  # Correct parameter name for ZIP search
        'enumeration_type': entity_type,
        'limit': search_limit,
        'skip': search_skip,
    }

    try:
        response = requests.get(BASE_URL, params=params)
        response.raise_for_status() # Raise HTTPError for bad responses (4xx or 5xx)
        return response.json()
    except requests.exceptions.RequestException as e:
        print(f"Error fetching data for {entity_type} in {zip_code}: {e}")
        return None

def parse_npi_results(data, entity_type):
    """Safely extracts and formats relevant data from the nested JSON structure."""
    records = []

    for item in data.get('results', []):
        basic = item.get('basic', {})
        # Use a default empty list/dictionary for nested fields to avoid crashes
        addresses = item.get('addresses', [{}])
        address = addresses[0] if addresses else {}
        taxonomy_list = item.get('taxonomies', [{}])

        # Determine Name based on entity type
        if entity_type == 'NPI-2': # Organization (Clinic/Hospital)
            full_name = basic.get('organization_name', 'N/A')

        else: # NPI-1 (Individual Doctor/Provider)
            first = basic.get('first_name', '')
            last = basic.get('last_name', '')
            credential = basic.get('credential', '')
            # Cleanly format the doctor's name
            full_name = f"{first} {last}, {credential}".strip().replace(" ,", "") or 'N/A'

        record = {
            'NPI_Type': entity_type,
            'Name': full_name,
            'Address_Line_1': address.get('address_1', 'N/A'),
            'City': address.get('city', 'N/A'),
            'State': address.get('state', 'N/A'),
            'NPI_Number': item.get('number', 'N/A'),
            # Safely access the primary taxonomy description
            'Primary_Taxonomy': taxonomy_list[0].get('desc', 'N/A') if taxonomy_list and isinstance(taxonomy_list, list) else 'N/A',
            'Title': basic.get('sole_proprietor', 'Organization') if entity_type == 'NPI-1' else 'Organization'
        }

        # Only include the record if the NPI number (the unique ID) is present
        if record['NPI_Number'] != 'N/A':
             records.append(record)
    return records

def get_all_records_by_zip(zip_code, entity_type):
    """Handles pagination for a single ZIP code query."""
    all_data = []
    skip = 0

    print(f"\n--- Searching for {entity_type} in ZIP {zip_code} ---")

    while True:
        data = fetch_npi_data(zip_code, entity_type, LIMIT, skip)

        if data is None:
            break

        results = data.get('results', [])
        current_count = len(results)

        print(f"  -> Retrieved {current_count} records. Total skip count: {skip}")

        if not results:
            break

        all_data.extend(parse_npi_results(data, entity_type))

        # Stop condition: reached end of results (current_count < LIMIT) or max skip limit
        if current_count < LIMIT or skip >= MAX_SKIP:
            break

        skip += LIMIT

    return all_data

# %%
# --- MAIN EXECUTION FUNCTION ---

def run_comprehensive_search():
    """Loops through all ZIP codes, fetches data, and consolidates the final DataFrame."""
    all_combined_records = []

    for zip_code in EL_PASO_ZIPS:
        # 1. Fetch Type 1 (Individual Doctors/Providers)
        doctor_records = get_all_records_by_zip(zip_code, 'NPI-1')
        all_combined_records.extend(doctor_records)

        # 2. Fetch Type 2 (Hospitals/Clinics/Organizations)
        facility_records = get_all_records_by_zip(zip_code, 'NPI-2')
        all_combined_records.extend(facility_records)

        # Be courteous to the API service by adding a small pause between batches
        time.sleep(0.5)

    # --- Consolidation ---
    print("\n--- CONSOLIDATING RESULTS ---")

    # Check the raw count before DataFrame conversion
    print(f"DEBUG: Raw total records collected before deduplication: {len(all_combined_records)}")

    # Convert to DataFrame
    final_df = pd.DataFrame(all_combined_records)

    if final_df.empty:
        return final_df

    # Deduplicate the list using the unique NPI_Number
    final_df_deduped = final_df.drop_duplicates(subset=['NPI_Number'])

    return final_df_deduped

# %%
# --- RUN SCRIPT ---
if __name__ == "__main__":
    final_directory = run_comprehensive_search()

    print("\n--- FINAL NPI DIRECTORY SUMMARY ---")
    print(f"✅ Total unique providers found across all ZIP codes: {len(final_directory)}")

    if not final_directory.empty:
        # Save the results to a CSV file
        final_directory.to_csv('el_paso_comprehensive_npi_directory.csv', index=False)
        print("File saved successfully as 'el_paso_comprehensive_npi_directory.csv'")
        print("\n--- Sample Records ---")
        print(final_directory.head())
    else:
        print("No records were found. Check API connectivity and ZIP code list.")
# Out:
# --- Searching for NPI-1 in ZIP 79901 ---
#   -> Retrieved 200 records. Total skip count: 0
#   -> Retrieved 200 records. Total skip count: 200
#   -> Retrieved 200 records. Total skip count: 400
#   -> Retrieved 200 records. Total skip count: 600
#   -> Retrieved 153 records. Total skip count: 800
#
# --- Searching for NPI-2 in ZIP 79901 ---
#   -> Retrieved 84 records. Total skip count: 0
#
# --- Searching for NPI-1 in ZIP 79902 ---
#   -> Retrieved 200 records. Total skip count: 0
#   -> Retrieved 200 records. Total skip count: 200
#   -> Retrieved 200 records. Total skip count: 400
#   -> Retrieved 200 records. Total skip count: 600
#   -> Retrieved 200 records. Total skip count: 800
#   -> Retrieved 200 records. Total skip count: 1000
#
# --- Searching for NPI-2 in ZIP 79902 ---
#   -> Retrieved 200 records. Total skip count: 0
#   -> Retrieved 200 records. Total skip count: 200
#   -> Retrieved 200 records. Total skip count: 400
#   -> Retrieved 152 records. Total skip count: 600
#
# --- Searching for NPI-1 in ZIP 79903 ---
#   -> Retrieved 200 records. Total skip count: 0
#   -> Retrieved 104 records. Total skip count: 200
#
# --- Searching for NPI-2 in ZIP 79903 ---
#   -> Retrieved 171 records. Total skip count: 0
#
# --- Searching for NPI-1 in ZIP 79904 ---
#   -> Retrieved 200 records. Total skip count: 0
#   -> Retrieved 37 records. Total skip count: 200
#
# --- Searching for NPI-2 in ZIP 79904 ---
#   -> Retrieved 72 records. Total skip count: 0
#
# --- Searching for NPI-1 in ZIP 79905 ---
#   -> Retrieved 200 records. Total skip count: 0
#   -> Retrieved 200 records. Total skip count: 200
#   -> Retrieved 200 records. Total skip count: 400
#   -> Retrieved 200 records. Total skip count: 600
#   -> Retrieved 200 records. Total skip count: 800
#   -> Retrieved 200 records. Total skip count: 1000
#
# --- Searching for NPI-2 in ZIP 79905 ---
#   -> Retrieved 200 records. Total skip count: 0
#   -> Retrieved 76 records. Total skip count: 200
#
# --- Searching for NPI-1 in ZIP 79906 ---
#   -> Retrieved 200 records. Total skip count: 0
#   -> Retrieved 200 records. Total skip count: 200
#   -> Retrieved 104 records. Total skip count: 400
#
# --- Searching for NPI-2 in ZIP 79906 ---
#   -> Retrieved 15 records. Total skip count: 0
#
# --- Searching for NPI-1 in ZIP 79907 ---
#   -> Retrieved 200 records. Total skip count: 0
#   -> Retrieved 77 records. Total skip count: 200
#
# --- Searching for NPI-2 in ZIP 79907 ---
#   -> Retrieved 109 records. Total skip count: 0
#
# --- Searching for NPI-1 in ZIP 79908 ---
#   -> Retrieved 39 records. Total skip count: 0
#
# --- Searching for NPI-2 in ZIP 79908 ---
#   -> Retrieved 2 records. Total skip count: 0
#
# --- Searching for NPI-1 in ZIP 79910 ---
#   -> Retrieved 0 records. Total skip count: 0
#
# --- Searching for NPI-2 in ZIP 79910 ---
#   -> Retrieved 0 records. Total skip count: 0
#
# --- Searching for NPI-1 in ZIP 79911 ---
#   -> Retrieved 200 records. Total skip count: 0
#   -> Retrieved 123 records. Total skip count: 200
#
# --- Searching for NPI-2 in ZIP 79911 ---
#   -> Retrieved 76 records. Total skip count: 0
#
# --- Searching for NPI-1 in ZIP 79912 ---
#   -> Retrieved 200 records. Total skip count: 0
#   -> Retrieved 200 records. Total skip count: 200
#   -> Retrieved 200 records. Total skip count: 400
#   -> Retrieved 200 records. Total skip count: 600
#   -> Retrieved 200 records. Total skip count: 800
#   -> Retrieved 200 records. Total skip count: 1000
#
# --- Searching for NPI-2 in ZIP 79912 ---
#   -> Retrieved 200 records. Total skip count: 0
#   -> Retrieved 200 records. Total skip count: 200
#   -> Retrieved 200 records. Total skip count: 400
#   -> Retrieved 53 records. Total skip count: 600
#
# --- Searching for NPI-1 in ZIP 79913 ---
#   -> Retrieved 69 records. Total skip count: 0
#
# --- Searching for NPI-2 in ZIP 79913 ---
#   -> Retrieved 96 records. Total skip count: 0
#
# --- Searching for NPI-1 in ZIP 79914 ---
#   -> Retrieved 4 records. Total skip count: 0
#
# --- Searching for NPI-2 in ZIP 79914 ---
#   -> Retrieved 1 records. Total skip count: 0
#
# --- Searching for NPI-1 in ZIP 79915 ---
#   -> Retrieved 200 records. Total skip count: 0
#   -> Retrieved 132 records. Total skip count: 200
#
# --- Searching for NPI-2 in ZIP 79915 ---
#   -> Retrieved 100 records. Total skip count: 0
#
# --- Searching for NPI-1 in ZIP 79916 ---
#   -> Retrieved 76 records. Total skip count: 0
#
# --- Searching for NPI-2 in ZIP 79916 ---
#   -> Retrieved 4 records. Total skip count: 0
#
# --- Searching for NPI-1 in ZIP 79917 ---
#   -> Retrieved 4 records. Total skip count: 0
#
# --- Searching for NPI-2 in ZIP 79917 ---
#   -> Retrieved 5 records. Total skip count: 0
#
# --- Searching for NPI-1 in ZIP 79918 ---
#   -> Retrieved 112 records. Total skip count: 0
#
# --- Searching for NPI-2 in ZIP 79918 ---
#   -> Retrieved 4 records. Total skip count: 0
#
# --- Searching for NPI-1 in ZIP 79920 ---
#   -> Retrieved 200 records. Total skip count: 0
#   -> Retrieved 200 records. Total skip count: 200
#   -> Retrieved 89 records. Total skip count: 400
#
# --- Searching for NPI-2 in ZIP 79920 ---
#   -> Retrieved 28 records. Total skip count: 0
#
# --- Searching for NPI-1 in ZIP 79922 ---
#   -> Retrieved 149 records. Total skip count: 0
#
# --- Searching for NPI-2 in ZIP 79922 ---
#   -> Retrieved 39 records. Total skip count: 0
#
# --- Searching for NPI-1 in ZIP 79923 ---
#   -> Retrieved 31 records. Total skip count: 0
#
# --- Searching for NPI-2 in ZIP 79923 ---
#   -> Retrieved 8 records. Total skip count: 0
#
# --- Searching for NPI-1 in ZIP 79924 ---
#   -> Retrieved 200 records. Total skip count: 0
#   -> Retrieved 200 records. Total skip count: 200
#   -> Retrieved 63 records. Total skip count: 400
#
# --- Searching for NPI-2 in ZIP 79924 ---
#   -> Retrieved 126 records. Total skip count: 0
#
# --- Searching for NPI-1 in ZIP 79925 ---
#   -> Retrieved 200 records. Total skip count: 0
#   -> Retrieved 200 records. Total skip count: 200
#   -> Retrieved 200 records. Total skip count: 400
#   -> Retrieved 200 records. Total skip count: 600
#   -> Retrieved 200 records. Total skip count: 800
#   -> Retrieved 200 records. Total skip count: 1000
#
# --- Searching for NPI-2 in ZIP 79925 ---
#   -> Retrieved 200 records. Total skip count: 0
#   -> Retrieved 200 records. Total skip count: 200
#   -> Retrieved 144 records. Total skip count: 400
#
# --- Searching for NPI-1 in ZIP 79926 ---
#   -> Retrieved 4 records. Total skip count: 0
#
# --- Searching for NPI-2 in ZIP 79926 ---
#   -> Retrieved 12 records. Total skip count: 0
#
# --- Searching for NPI-1 in ZIP 79927 ---
#   -> Retrieved 152 records. Total skip count: 0
#
# --- Searching for NPI-2 in ZIP 79927 ---
#   -> Retrieved 64 records. Total skip count: 0
#
# --- Searching for NPI-1 in ZIP 79928 ---
#   -> Retrieved 200 records. Total skip count: 0
#   -> Retrieved 200 records. Total skip count: 200
#   -> Retrieved 115 records. Total skip count: 400
#
# --- Searching for NPI-2 in ZIP 79928 ---
#   -> Retrieved 129 records. Total skip count: 0
#
# --- Searching for NPI-1 in ZIP 79929 ---
#   -> Retrieved 5 records. Total skip count: 0
#
# --- Searching for NPI-2 in ZIP 79929 ---
#   -> Retrieved 3 records. Total skip count: 0
#
# --- Searching for NPI-1 in ZIP 79930 ---
#   -> Retrieved 200 records. Total skip count: 0
#   -> Retrieved 200 records. Total skip count: 200
#   -> Retrieved 98 records. Total skip count: 400
#
# --- Searching for NPI-2 in ZIP 79930 ---
#   -> Retrieved 50 records. Total skip count: 0
#
# --- Searching for NPI-1 in ZIP 79931 ---
#   -> Retrieved 2 records. Total skip count: 0
#
# --- Searching for NPI-2 in ZIP 79931 ---
#   -> Retrieved 1 records. Total skip count: 0
#
# --- Searching for NPI-1 in ZIP 79932 ---
#   -> Retrieved 200 records. Total skip count: 0
#   -> Retrieved 148 records. Total skip count: 200
#
# --- Searching for NPI-2 in ZIP 79932 ---
#   -> Retrieved 107 records. Total skip count: 0
#
# --- Searching for NPI-1 in ZIP 79934 ---
#   -> Retrieved 200 records. Total skip count: 0
#   -> Retrieved 74 records. Total skip count: 200
#
# --- Searching for NPI-2 in ZIP 79934 ---
#   -> Retrieved 45 records. Total skip count: 0
#
# --- Searching for NPI-1 in ZIP 79935 ---
#   -> Retrieved 200 records. Total skip count: 0
#   -> Retrieved 200 records. Total skip count: 200
#   -> Retrieved 94 records. Total skip count: 400
#
# --- Searching for NPI-2 in ZIP 79935 ---
#   -> Retrieved 200 records. Total skip count: 0
#   -> Retrieved 38 records. Total skip count: 200
#
# --- Searching for NPI-1 in ZIP 79936 ---
#   -> Retrieved 200 records. Total skip count: 0
#   -> Retrieved 200 records. Total skip count: 200
#   -> Retrieved 200 records. Total skip count: 400
#   -> Retrieved 200 records. Total skip count: 600
#   -> Retrieved 200 records. Total skip count: 800
#   -> Retrieved 200 records. Total skip count: 1000
#
# --- Searching for NPI-2 in ZIP 79936 ---
#   -> Retrieved 200 records. Total skip count: 0
#   -> Retrieved 200 records. Total skip count: 200
#   -> Retrieved 200 records. Total skip count: 400
#   -> Retrieved 88 records. Total skip count: 600
#
# --- Searching for NPI-1 in ZIP 79937 ---
#   -> Retrieved 12 records. Total skip count: 0
#
# --- Searching for NPI-2 in ZIP 79937 ---
#   -> Retrieved 9 records. Total skip count: 0
#
# --- Searching for NPI-1 in ZIP 79938 ---
#   -> Retrieved 200 records. Total skip count: 0
#   -> Retrieved 200 records. Total skip count: 200
#   -> Retrieved 200 records. Total skip count: 400
#   -> Retrieved 200 records. Total skip count: 600
#   -> Retrieved 33 records. Total skip count: 800
#
# --- Searching for NPI-2 in ZIP 79938 ---
#   -> Retrieved 200 records. Total skip count: 0
#   -> Retrieved 29 records. Total skip count: 200
#
# --- Searching for NPI-1 in ZIP 79940 ---
#   -> Retrieved 1 records. Total skip count: 0
#
# --- Searching for NPI-2 in ZIP 79940 ---
#   -> Retrieved 1 records. Total skip count: 0
#
# --- Searching for NPI-1 in ZIP 79941 ---
#   -> Retrieved 0 records. Total skip count: 0
#
# --- Searching for NPI-2 in ZIP 79941 ---
#   -> Retrieved 1 records. Total skip count: 0
#
# --- Searching for NPI-1 in ZIP 79942 ---
#   -> Retrieved 0 records. Total skip count: 0
#
# --- Searching for NPI-2 in ZIP 79942 ---
#   -> Retrieved 1 records. Total skip count: 0
#
# --- Searching for NPI-1 in ZIP 79943 ---
#   -> Retrieved 0 records. Total skip count: 0
#
# --- Searching for NPI-2 in ZIP 79943 ---
#   -> Retrieved 0 records. Total skip count: 0
#
# --- Searching for NPI-1 in ZIP 79944 ---
#   -> Retrieved 1 records. Total skip count: 0
#
# --- Searching for NPI-2 in ZIP 79944 ---
#   -> Retrieved 0 records. Total skip count: 0
#
# --- Searching for NPI-1 in ZIP 79945 ---
#   -> Retrieved 0 records. Total skip count: 0
#
# --- Searching for NPI-2 in ZIP 79945 ---
#   -> Retrieved 0 records. Total skip count: 0
#
# --- Searching for NPI-1 in ZIP 79946 ---
#   -> Retrieved 0 records. Total skip count: 0
#
# --- Searching for NPI-2 in ZIP 79946 ---
#   -> Retrieved 0 records. Total skip count: 0
#
# --- Searching for NPI-1 in ZIP 79947 ---
#   -> Retrieved 0 records. Total skip count: 0
#
# --- Searching for NPI-2 in ZIP 79947 ---
#   -> Retrieved 0 records. Total skip count: 0
#
# --- Searching for NPI-1 in ZIP 79948 ---
#   -> Retrieved 0 records. Total skip count: 0
#
# --- Searching for NPI-2 in ZIP 79948 ---
#   -> Retrieved 0 records. Total skip count: 0
#
# --- Searching for NPI-1 in ZIP 79949 ---
#   -> Retrieved 0 records. Total skip count: 0
#
# --- Searching for NPI-2 in ZIP 79949 ---
#   -> Retrieved 1 records. Total skip count: 0
#
# --- Searching for NPI-1 in ZIP 79950 ---
#   -> Retrieved 0 records. Total skip count: 0
#
# --- Searching for NPI-2 in ZIP 79950 ---
#   -> Retrieved 0 records. Total skip count: 0
#
# --- Searching for NPI-1 in ZIP 79951 ---
#   -> Retrieved 0 records. Total skip count: 0
#
# --- Searching for NPI-2 in ZIP 79951 ---
#   -> Retrieved 5 records. Total skip count: 0
#
# --- Searching for NPI-1 in ZIP 79952 ---
#   -> Retrieved 1 records. Total skip count: 0
#
# --- Searching for NPI-2 in ZIP 79952 ---
#   -> Retrieved 0 records. Total skip count: 0
#
# --- Searching for NPI-1 in ZIP 79953 ---
#   -> Retrieved 0 records. Total skip count: 0
#
# --- Searching for NPI-2 in ZIP 79953 ---
#   -> Retrieved 0 records. Total skip count: 0
#
# --- Searching for NPI-1 in ZIP 79954 ---
#   -> Retrieved 1 records. Total skip count: 0
#
# --- Searching for NPI-2 in ZIP 79954 ---
#   -> Retrieved 0 records. Total skip count: 0
#
# --- Searching for NPI-1 in ZIP 79955 ---
#   -> Retrieved 0 records. Total skip count: 0
#
# --- Searching for NPI-2 in ZIP 79955 ---
#   -> Retrieved 0 records. Total skip count: 0
#
# --- Searching for NPI-1 in ZIP 79958 ---
#   -> Retrieved 0 records. Total skip count: 0
#
# --- Searching for NPI-2 in ZIP 79958 ---
#   -> Retrieved 0 records. Total skip count: 0
#
# --- Searching for NPI-1 in ZIP 79960 ---
#   -> Retrieved 0 records. Total skip count: 0
#
# --- Searching for NPI-2 in ZIP 79960 ---
#   -> Retrieved 0 records. Total skip count: 0
#
# --- Searching for NPI-1 in ZIP 79961 ---
#   -> Retrieved 0 records. Total skip count: 0
#
# --- Searching for NPI-2 in ZIP 79961 ---
#   -> Retrieved 0 records. Total skip count: 0
#
# --- Searching for NPI-1 in ZIP 79968 ---
#   -> Retrieved 23 records. Total skip count: 0
#
# --- Searching for NPI-2 in ZIP 79968 ---
#   -> Retrieved 2 records. Total skip count: 0
#
# --- Searching for NPI-1 in ZIP 79976 ---
#   -> Retrieved 0 records. Total skip count: 0
#
# --- Searching for NPI-2 in ZIP 79976 ---
#   -> Retrieved 0 records. Total skip count: 0
#
# --- Searching for NPI-1 in ZIP 79978 ---
#   -> Retrieved 0 records. Total skip count: 0
#
# --- Searching for NPI-2 in ZIP 79978 ---
#   -> Retrieved 0 records. Total skip count: 0
#
# --- Searching for NPI-1 in ZIP 79980 ---
#   -> Retrieved 0 records. Total skip count: 0
#
# --- Searching for NPI-2 in ZIP 79980 ---
#   -> Retrieved 0 records. Total skip count: 0
#
# --- Searching for NPI-1 in ZIP 79990 ---
#   -> Retrieved 0 records. Total skip count: 0
#
# --- Searching for NPI-2 in ZIP 79990 ---
#   -> Retrieved 0 records. Total skip count: 0
#
# --- Searching for NPI-1 in ZIP 79995 ---
#   -> Retrieved 91 records. Total skip count: 0
#
# --- Searching for NPI-2 in ZIP 79995 ---
#   -> Retrieved 33 records. Total skip count: 0
#
# --- Searching for NPI-1 in ZIP 79996 ---
#   -> Retrieved 44 records. Total skip count: 0
#
# --- Searching for NPI-2 in ZIP 79996 ---
#   -> Retrieved 17 records. Total skip count: 0
#
# --- Searching for NPI-1 in ZIP 79997 ---
#   -> Retrieved 14 records. Total skip count: 0
#
# --- Searching for NPI-2 in ZIP 79997 ---
#   -> Retrieved 16 records. Total skip count: 0
#
# --- Searching for NPI-1 in ZIP 79998 ---
#   -> Retrieved 0 records. Total skip count: 0
#
# --- Searching for NPI-2 in ZIP 79998 ---
#   -> Retrieved 0 records. Total skip count: 0
#
# --- Searching for NPI-1 in ZIP 79999 ---
#   -> Retrieved 0 records. Total skip count: 0
#
# --- Searching for NPI-2 in ZIP 79999 ---
#   -> Retrieved 0 records. Total skip count: 0
#
# --- CONSOLIDATING RESULTS ---
# DEBUG: Raw total records collected before deduplication: 18496
#
# --- FINAL NPI DIRECTORY SUMMARY ---
# ✅ Total unique providers found across all ZIP codes: 15073
# File saved successfully as 'el_paso_comprehensive_npi_directory.csv'
#
# --- Sample Records ---
#   NPI_Type                       Name           Address_Line_1        City  \
# 0    NPI-1       BARBARA ABALOS, BCBA        1211 8TH ST STE C  ALAMOGORDO
# 1    NPI-1          SAMUEL ABOUD, RPh           700 S OCHOA ST     EL PASO
# 2    NPI-1  MOHAMMAD ABOUKHADIJA, DDS           700 S OCHOA ST     EL PASO
# 3    NPI-1      ISABEL ACOSTA VALDES,           1619 NE 8TH ST   HOMESTEAD
# 4    NPI-1           JENNIFER ADCOCK,  221 N KANSAS ST STE 700     EL PASO
#
#   State  NPI_Number           Primary_Taxonomy Title
# 0    NM  1033652979           Behavior Analyst    NO
# 1    TX  1699111955                 Pharmacist    NO
# 2    TX  1144923764  Dentist, General Practice    NO
# 3    FL  1043678485  Dentist, General Practice   YES
# 4    TX  1538838867           Behavior Analyst   YES

# %%
import requests
import pandas as pd
import time

# --- Configuration ---
# Comprehensive list of El Paso, TX ZIP codes
EL_PASO_ZIPS = [
    "79901", "79902", "79903", "79904", "79905", "79906", "79907",
    "79908", "79910", "79911", "79912", "79913", "79914", "79915",
    "79916", "79917", "79918", "79920", "79922", "79923", "79924",
    "79925", "79926", "79927", "79928", "79929", "79930", "79931",
    "79932", "79934", "79935", "79936", "79937", "79938", "79940",
    "79941", "79942", "79943", "79944", "79945", "79946", "79947",
    "79948", "79949", "79950", "79951", "79952", "79953", "79954",
    "79955", "79958", "79960", "79961", "79968", "79976", "79978",
    "79980", "79990", "79995", "79996", "79997", "79998", "79999"
]
BASE_URL = "https://npiregistry.cms.hhs.gov/api/"
LIMIT = 200  # Max records per request
MAX_SKIP = 1000 # Max skip allowed by NPI API (allowing 1200 records per ZIP/type)

# --- NPI API COMMUNICATION FUNCTIONS ---

def fetch_npi_data(zip_code, entity_type, search_limit, search_skip):
    """Makes a single paginated request to the NPI API."""
    params = {
        'version': '2.1',
        'postal_code': zip_code,  # Correct parameter for ZIP search
        'enumeration_type': entity_type,
        'limit': search_limit,
        'skip': search_skip,
    }

    try:
        response = requests.get(BASE_URL, params=params)
        response.raise_for_status() # Raise HTTPError for bad responses (4xx or 5xx)
        return response.json()
    except requests.exceptions.RequestException as e:
        # Added print statement to debug connection or API errors
        print(f"Error fetching data for {entity_type} in {zip_code}: {e}")
        return None

def parse_npi_results(data, entity_type):
    """Safely extracts, formats, and creates the linking key for records."""
    records = []

    for item in data.get('results', []):
        basic = item.get('basic', {})
        addresses = item.get('addresses', [{}])
        address = addresses[0] if addresses else {}
        taxonomy_list = item.get('taxonomies', [{}])

        # Determine Name based on entity type
        if entity_type == 'NPI-2': # Organization (Clinic/Hospital)
            full_name = basic.get('organization_name', 'N/A')

        else: # NPI-1 (Individual Doctor/Provider)
            first = basic.get('first_name', '')
            last = basic.get('last_name', '')
            credential = basic.get('credential', '')
            full_name = f"{first} {last}, {credential}".strip().replace(" ,", "") or 'N/A'

        # --- CRITICAL: ADDRESS LINKING KEY CREATION ---
        addr_line_1 = address.get('address_1', 'N/A').upper().strip()
        addr_city = address.get('city', 'N/A').upper().strip()
        linking_key = f"{addr_line_1}, {addr_city}"

        record = {
            'NPI_Type': entity_type,
            'NPI_Number': item.get('number', 'N/A'),
            'Name': full_name,
            'Primary_Taxonomy': taxonomy_list[0].get('desc', 'N/A') if taxonomy_list and isinstance(taxonomy_list, list) else 'N/A',
            'Address_Line_1': addr_line_1,
            'City': addr_city,
            'State': address.get('state', 'N/A'),
            'Linking_Key': linking_key, # The standardized key for merging
        }

        if record['NPI_Number'] != 'N/A':
             records.append(record)
    return records

def get_all_records_by_zip(zip_code, entity_type):
    """Handles pagination for a single ZIP code query."""
    all_data = []
    skip = 0

    print(f"\n--- Searching for {entity_type} in ZIP {zip_code} ---")

    while True:
        data = fetch_npi_data(zip_code, entity_type, LIMIT, skip)

        if data is None:
            break

        results = data.get('results', [])
        current_count = len(results)

        print(f"  -> Retrieved {current_count} records. Total skip count: {skip}")

        if not results:
            break

        all_data.extend(parse_npi_results(data, entity_type))

        if current_count < LIMIT or skip >= MAX_SKIP:
            break

        skip += LIMIT

    return all_data

# --- MAIN LINKING EXECUTION FUNCTION ---

def run_linking_search():
    """Fetches all data, cleans it, and links doctors to facilities by address."""
    all_doctor_records = []
    all_facility_records = []

    for zip_code in EL_PASO_ZIPS:
        # 1. Fetch Type 2 (Hospitals/Clinics/Organizations) first
        facility_records = get_all_records_by_zip(zip_code, 'NPI-2')
        all_facility_records.extend(facility_records)

        # 2. Fetch Type 1 (Individual Doctors/Providers)
        doctor_records = get_all_records_by_zip(zip_code, 'NPI-1')
        all_doctor_records.extend(doctor_records)

        time.sleep(0.5)

    # --- Step A: Clean and Deduplicate DataFrames ---
    print("\n--- Cleaning and Deduplicating Data ---")

    # Deduplicate facilities based on unique NPI
    df_facilities = pd.DataFrame(all_facility_records).drop_duplicates(subset=['NPI_Number'])
    # Deduplicate doctors based on unique NPI
    df_doctors = pd.DataFrame(all_doctor_records).drop_duplicates(subset=['NPI_Number'])

    print(f"Total Unique Facilities: {len(df_facilities)}")
    print(f"Total Unique Doctors: {len(df_doctors)}")

    # --- Step B: Select Facility Data and Prepare for Matching ---
    # We only need the key columns from the facility list for the merge
    facility_match_cols = df_facilities[['Linking_Key', 'NPI_Number', 'Name', 'Primary_Taxonomy', 'Address_Line_1']]
    facility_match_cols = facility_match_cols.rename(columns={
        'NPI_Number': 'Facility_NPI',
        'Name': 'Facility_Name',
        'Primary_Taxonomy': 'Facility_Type',
        'Address_Line_1': 'Facility_Address'
    })

    # --- Step C: Perform the Merge (Linking) ---
    # Merge the doctor data (left side) with the facility data (right side) on the shared address key.
    # 'how=left' ensures all doctors are kept, even those who don't match a facility.
    df_linked = pd.merge(
        df_doctors,
        facility_match_cols,
        on='Linking_Key',
        how='left'
    )

    # --- Step D: Final Cleanup ---
    # Fill NaN values for unlinked doctors
    df_linked['Facility_Name'] = df_linked['Facility_Name'].fillna('Independent/Unlinked')
    df_linked['Facility_NPI'] = df_linked['Facility_NPI'].fillna('N/A')
    df_linked['Facility_Type'] = df_linked['Facility_Type'].fillna('N/A')

    # Drop the redundant address columns after merging
    df_linked = df_linked.drop(columns=['Linking_Key', 'Address_Line_1', 'City', 'State'])

    return df_linked

# --- RUN SCRIPT ---
if __name__ == "__main__":
    linked_directory = run_linking_search()

    print("\n--- FINAL LINKED NPI DIRECTORY SUMMARY ---")
    print(f"✅ Total unique doctor records processed and linked: {len(linked_directory)}")

    if not linked_directory.empty:
        # Save the results to a CSV file
        linked_directory.to_csv('el_paso_linked_directory.csv', index=False)
        print("File saved successfully as 'el_paso_linked_directory.csv'")

        print("\n--- Sample Linked Records (Showing Doctor to Facility Match) ---")
        # Select key output columns to show the successful link
        sample = linked_directory[['Name', 'Primary_Taxonomy', 'Facility_Name', 'Facility_Address']].head(10)
        print(sample)
    else:
        print("No records were found. Please verify NPI API accessibility.")
# Out:
# --- Searching for NPI-2 in ZIP 79901 ---
#   -> Retrieved 85 records. Total skip count: 0
#
# --- Searching for NPI-1 in ZIP 79901 ---
#   -> Retrieved 200 records. Total skip count: 0
#   -> Retrieved 200 records. Total skip count: 200
#   -> Retrieved 200 records. Total skip count: 400
#   -> Retrieved 200 records. Total skip count: 600
#   -> Retrieved 157 records. Total skip count: 800
#
# --- Searching for NPI-2 in ZIP 79902 ---
#   -> Retrieved 200 records. Total skip count: 0
#   -> Retrieved 200 records. Total skip count: 200
#   -> Retrieved 200 records. Total skip count: 400
#   -> Retrieved 152 records. Total skip count: 600
#
# --- Searching for NPI-1 in ZIP 79902 ---
#   -> Retrieved 200 records. Total skip count: 0
#   -> Retrieved 200 records. Total skip count: 200
#   -> Retrieved 200 records. Total skip count: 400
#   -> Retrieved 200 records. Total skip count: 600
#   -> Retrieved 200 records. Total skip count: 800
#   -> Retrieved 200 records. Total skip count: 1000
#
# --- Searching for NPI-2 in ZIP 79903 ---
#   -> Retrieved 169 records. Total skip count: 0
#
# --- Searching for NPI-1 in ZIP 79903 ---
#   -> Retrieved 200 records. Total skip count: 0
#   -> Retrieved 104 records. Total skip count: 200
#
# --- Searching for NPI-2 in ZIP 79904 ---
#   -> Retrieved 74 records. Total skip count: 0
#
# --- Searching for NPI-1 in ZIP 79904 ---
#   -> Retrieved 200 records. Total skip count: 0
#   -> Retrieved 37 records. Total skip count: 200
#
# --- Searching for NPI-2 in ZIP 79905 ---
#   -> Retrieved 200 records. Total skip count: 0
#   -> Retrieved 77 records. Total skip count: 200
#
# --- Searching for NPI-1 in ZIP 79905 ---
#   -> Retrieved 200 records. Total skip count: 0
#   -> Retrieved 200 records. Total skip count: 200
#   -> Retrieved 200 records. Total skip count: 400
#   -> Retrieved 200 records. Total skip count: 600
#   -> Retrieved 200 records. Total skip count: 800
#   -> Retrieved 200 records. Total skip count: 1000
#
# --- Searching for NPI-2 in ZIP 79906 ---
#   -> Retrieved 15 records. Total skip count: 0
#
# --- Searching for NPI-1 in ZIP 79906 ---
#   -> Retrieved 200 records. Total skip count: 0
#   -> Retrieved 200 records. Total skip count: 200
#   -> Retrieved 104 records. Total skip count: 400
#
# --- Searching for NPI-2 in ZIP 79907 ---
#   -> Retrieved 110 records. Total skip count: 0
#
# --- Searching for NPI-1 in ZIP 79907 ---
#   -> Retrieved 200 records. Total skip count: 0
#   -> Retrieved 78 records. Total skip count: 200
#
# --- Searching for NPI-2 in ZIP 79908 ---
#   -> Retrieved 2 records. Total skip count: 0
#
# --- Searching for NPI-1 in ZIP 79908 ---
#   -> Retrieved 40 records. Total skip count: 0
#
# --- Searching for NPI-2 in ZIP 79910 ---
#   -> Retrieved 0 records. Total skip count: 0
#
# --- Searching for NPI-1 in ZIP 79910 ---
#   -> Retrieved 0 records. Total skip count: 0
#
# --- Searching for NPI-2 in ZIP 79911 ---
#   -> Retrieved 76 records. Total skip count: 0
#
# --- Searching for NPI-1 in ZIP 79911 ---
#   -> Retrieved 200 records. Total skip count: 0
#   -> Retrieved 122 records. Total skip count: 200
#
# --- Searching for NPI-2 in ZIP 79912 ---
#   -> Retrieved 200 records. Total skip count: 0
#   -> Retrieved 200 records. Total skip count: 200
#   -> Retrieved 200 records. Total skip count: 400
#   -> Retrieved 54 records. Total skip count: 600
#
# --- Searching for NPI-1 in ZIP 79912 ---
#   -> Retrieved 200 records. Total skip count: 0
#   -> Retrieved 200 records. Total skip count: 200
#   -> Retrieved 200 records. Total skip count: 400
#   -> Retrieved 200 records. Total skip count: 600
#   -> Retrieved 200 records. Total skip count: 800
#   -> Retrieved 200 records. Total skip count: 1000
#
# --- Searching for NPI-2 in ZIP 79913 ---
#   -> Retrieved 96 records. Total skip count: 0
#
# --- Searching for NPI-1 in ZIP 79913 ---
#   -> Retrieved 69 records. Total skip count: 0
#
# --- Searching for NPI-2 in ZIP 79914 ---
#   -> Retrieved 1 records. Total skip count: 0
#
# --- Searching for NPI-1 in ZIP 79914 ---
#   -> Retrieved 4 records. Total skip count: 0
#
# --- Searching for NPI-2 in ZIP 79915 ---
#   -> Retrieved 101 records. Total skip count: 0
#
# --- Searching for NPI-1 in ZIP 79915 ---
#   -> Retrieved 200 records. Total skip count: 0
#   -> Retrieved 136 records. Total skip count: 200
#
# --- Searching for NPI-2 in ZIP 79916 ---
#   -> Retrieved 4 records. Total skip count: 0
#
# --- Searching for NPI-1 in ZIP 79916 ---
#   -> Retrieved 76 records. Total skip count: 0
#
# --- Searching for NPI-2 in ZIP 79917 ---
#   -> Retrieved 5 records. Total skip count: 0
#
# --- Searching for NPI-1 in ZIP 79917 ---
#   -> Retrieved 4 records. Total skip count: 0
#
# --- Searching for NPI-2 in ZIP 79918 ---
#   -> Retrieved 4 records. Total skip count: 0
#
# --- Searching for NPI-1 in ZIP 79918 ---
#   -> Retrieved 113 records. Total skip count: 0
#
# --- Searching for NPI-2 in ZIP 79920 ---
#   -> Retrieved 28 records. Total skip count: 0
#
# --- Searching for NPI-1 in ZIP 79920 ---
#   -> Retrieved 200 records. Total skip count: 0
#   -> Retrieved 200 records. Total skip count: 200
#   -> Retrieved 89 records. Total skip count: 400
#
# --- Searching for NPI-2 in ZIP 79922 ---
#   -> Retrieved 39 records. Total skip count: 0
#
# --- Searching for NPI-1 in ZIP 79922 ---
#   -> Retrieved 148 records. Total skip count: 0
#
# --- Searching for NPI-2 in ZIP 79923 ---
#   -> Retrieved 8 records. Total skip count: 0
#
# --- Searching for NPI-1 in ZIP 79923 ---
#   -> Retrieved 31 records. Total skip count: 0
#
# --- Searching for NPI-2 in ZIP 79924 ---
#   -> Retrieved 126 records. Total skip count: 0
#
# --- Searching for NPI-1 in ZIP 79924 ---
#   -> Retrieved 200 records. Total skip count: 0
#   -> Retrieved 200 records. Total skip count: 200
#   -> Retrieved 64 records. Total skip count: 400
#
# --- Searching for NPI-2 in ZIP 79925 ---
#   -> Retrieved 200 records. Total skip count: 0
#   -> Retrieved 200 records. Total skip count: 200
#   -> Retrieved 144 records. Total skip count: 400
#
# --- Searching for NPI-1 in ZIP 79925 ---
#   -> Retrieved 200 records. Total skip count: 0
#   -> Retrieved 200 records. Total skip count: 200
#   -> Retrieved 200 records. Total skip count: 400
#   -> Retrieved 200 records. Total skip count: 600
#   -> Retrieved 200 records. Total skip count: 800
#   -> Retrieved 200 records. Total skip count: 1000
#
# --- Searching for NPI-2 in ZIP 79926 ---
#   -> Retrieved 12 records. Total skip count: 0
#
# --- Searching for NPI-1 in ZIP 79926 ---
#   -> Retrieved 4 records. Total skip count: 0
#
# --- Searching for NPI-2 in ZIP 79927 ---
#   -> Retrieved 64 records. Total skip count: 0
#
# --- Searching for NPI-1 in ZIP 79927 ---
#   -> Retrieved 153 records. Total skip count: 0
#
# --- Searching for NPI-2 in ZIP 79928 ---
#   -> Retrieved 129 records. Total skip count: 0
#
# --- Searching for NPI-1 in ZIP 79928 ---
#   -> Retrieved 200 records. Total skip count: 0
#   -> Retrieved 200 records. Total skip count: 200
#   -> Retrieved 118 records. Total skip count: 400
#
# --- Searching for NPI-2 in ZIP 79929 ---
#   -> Retrieved 3 records. Total skip count: 0
#
# --- Searching for NPI-1 in ZIP 79929 ---
#   -> Retrieved 5 records. Total skip count: 0
#
# --- Searching for NPI-2 in ZIP 79930 ---
#   -> Retrieved 50 records. Total skip count: 0
#
# --- Searching for NPI-1 in ZIP 79930 ---
#   -> Retrieved 200 records. Total skip count: 0
#   -> Retrieved 200 records. Total skip count: 200
#   -> Retrieved 99 records. Total skip count: 400
#
# --- Searching for NPI-2 in ZIP 79931 ---
#   -> Retrieved 1 records. Total skip count: 0
#
# --- Searching for NPI-1 in ZIP 79931 ---
#   -> Retrieved 2 records. Total skip count: 0
#
# --- Searching for NPI-2 in ZIP 79932 ---
#   -> Retrieved 107 records. Total skip count: 0
#
# --- Searching for NPI-1 in ZIP 79932 ---
#   -> Retrieved 200 records. Total skip count: 0
#   -> Retrieved 146 records. Total skip count: 200
#
# --- Searching for NPI-2 in ZIP 79934 ---
#   -> Retrieved 45 records. Total skip count: 0
#
# --- Searching for NPI-1 in ZIP 79934 ---
#   -> Retrieved 200 records. Total skip count: 0
#   -> Retrieved 75 records. Total skip count: 200
#
# --- Searching for NPI-2 in ZIP 79935 ---
#   -> Retrieved 200 records. Total skip count: 0
#   -> Retrieved 40 records. Total skip count: 200
#
# --- Searching for NPI-1 in ZIP 79935 ---
#   -> Retrieved 200 records. Total skip count: 0
#   -> Retrieved 200 records. Total skip count: 200
#   -> Retrieved 94 records. Total skip count: 400
#
# --- Searching for NPI-2 in ZIP 79936 ---
#   -> Retrieved 200 records. Total skip count: 0
#   -> Retrieved 200 records. Total skip count: 200
#   -> Retrieved 200 records. Total skip count: 400
#   -> Retrieved 90 records. Total skip count: 600
#
# --- Searching for NPI-1 in ZIP 79936 ---
#   -> Retrieved 200 records. Total skip count: 0
#   -> Retrieved 200 records. Total skip count: 200
#   -> Retrieved 200 records. Total skip count: 400
#   -> Retrieved 200 records. Total skip count: 600
#   -> Retrieved 200 records. Total skip count: 800
#   -> Retrieved 200 records. Total skip count: 1000
#
# --- Searching for NPI-2 in ZIP 79937 ---
#   -> Retrieved 9 records. Total skip count: 0
#
# --- Searching for NPI-1 in ZIP 79937 ---
#   -> Retrieved 12 records. Total skip count: 0
#
# --- Searching for NPI-2 in ZIP 79938 ---
#   -> Retrieved 200 records. Total skip count: 0
#   -> Retrieved 30 records. Total skip count: 200
#
# --- Searching for NPI-1 in ZIP 79938 ---
#   -> Retrieved 200 records. Total skip count: 0
#   -> Retrieved 200 records. Total skip count: 200
#   -> Retrieved 200 records. Total skip count: 400
#   -> Retrieved 200 records. Total skip count: 600
#   -> Retrieved 37 records. Total skip count: 800
#
# --- Searching for NPI-2 in ZIP 79940 ---
#   -> Retrieved 1 records. Total skip count: 0
#
# --- Searching for NPI-1 in ZIP 79940 ---
#   -> Retrieved 1 records. Total skip count: 0
#
# --- Searching for NPI-2 in ZIP 79941 ---
#   -> Retrieved 1 records. Total skip count: 0
#
# --- Searching for NPI-1 in ZIP 79941 ---
#   -> Retrieved 0 records. Total skip count: 0
#
# --- Searching for NPI-2 in ZIP 79942 ---
#   -> Retrieved 1 records. Total skip count: 0
#
# --- Searching for NPI-1 in ZIP 79942 ---
#   -> Retrieved 0 records. Total skip count: 0
#
# --- Searching for NPI-2 in ZIP 79943 ---
#   -> Retrieved 0 records. Total skip count: 0
#
# --- Searching for NPI-1 in ZIP 79943 ---
#   -> Retrieved 0 records. Total skip count: 0
#
# --- Searching for NPI-2 in ZIP 79944 ---
#   -> Retrieved 0 records. Total skip count: 0
#
# --- Searching for NPI-1 in ZIP 79944 ---
#   -> Retrieved 1 records. Total skip count: 0
#
# --- Searching for NPI-2 in ZIP 79945 ---
#   -> Retrieved 0 records. Total skip count: 0
#
# --- Searching for NPI-1 in ZIP 79945 ---
#   -> Retrieved 0 records. Total skip count: 0
#
# --- Searching for NPI-2 in ZIP 79946 ---
#   -> Retrieved 0 records. Total skip count: 0
#
# --- Searching for NPI-1 in ZIP 79946 ---
#   -> Retrieved 0 records. Total skip count: 0
#
# --- Searching for NPI-2 in ZIP 79947 ---
#   -> Retrieved 0 records. Total skip count: 0
#
# --- Searching for NPI-1 in ZIP 79947 ---
#   -> Retrieved 0 records. Total skip count: 0
#
# --- Searching for NPI-2 in ZIP 79948 ---
#   -> Retrieved 0 records. Total skip count: 0
#
# --- Searching for NPI-1 in ZIP 79948 ---
#   -> Retrieved 0 records. Total skip count: 0
#
# --- Searching for NPI-2 in ZIP 79949 ---
#   -> Retrieved 1 records. Total skip count: 0
#
# --- Searching for NPI-1 in ZIP 79949 ---
#   -> Retrieved 0 records. Total skip count: 0
#
# --- Searching for NPI-2 in ZIP 79950 ---
#   -> Retrieved 0 records. Total skip count: 0
#
# --- Searching for NPI-1 in ZIP 79950 ---
#   -> Retrieved 0 records. Total skip count: 0
#
# --- Searching for NPI-2 in ZIP 79951 ---
#   -> Retrieved 5 records. Total skip count: 0
#
# --- Searching for NPI-1 in ZIP 79951 ---
#   -> Retrieved 0 records. Total skip count: 0
#
# --- Searching for NPI-2 in ZIP 79952 ---
#   -> Retrieved 0 records. Total skip count: 0
#
# --- Searching for NPI-1 in ZIP 79952 ---
#   -> Retrieved 1 records. Total skip count: 0
#
# --- Searching for NPI-2 in ZIP 79953 ---
#   -> Retrieved 0 records. Total skip count: 0
#
# --- Searching for NPI-1 in ZIP 79953 ---
#   -> Retrieved 0 records. Total skip count: 0
#
# --- Searching for NPI-2 in ZIP 79954 ---
#   -> Retrieved 0 records. Total skip count: 0
#
# --- Searching for NPI-1 in ZIP 79954 ---
#   -> Retrieved 1 records. Total skip count: 0
#
# --- Searching for NPI-2 in ZIP 79955 ---
#   -> Retrieved 0 records. Total skip count: 0
#
# --- Searching for NPI-1 in ZIP 79955 ---
#   -> Retrieved 0 records. Total skip count: 0
#
# --- Searching for NPI-2 in ZIP 79958 ---
#   -> Retrieved 0 records. Total skip count: 0
#
# --- Searching for NPI-1 in ZIP 79958 ---
#   -> Retrieved 0 records. Total skip count: 0
#
# --- Searching for NPI-2 in ZIP 79960 ---
#   -> Retrieved 0 records. Total skip count: 0
#
# --- Searching for NPI-1 in ZIP 79960 ---
#   -> Retrieved 0 records. Total skip count: 0
#
# --- Searching for NPI-2 in ZIP 79961 ---
#   -> Retrieved 0 records. Total skip count: 0
#
# --- Searching for NPI-1 in ZIP 79961 ---
#   -> Retrieved 0 records. Total skip count: 0
#
# --- Searching for NPI-2 in ZIP 79968 ---
#   -> Retrieved 2 records. Total skip count: 0
#
# --- Searching for NPI-1 in ZIP 79968 ---
#   -> Retrieved 23 records. Total skip count: 0
#
# --- Searching for NPI-2 in ZIP 79976 ---
#   -> Retrieved 0 records. Total skip count: 0
#
# --- Searching for NPI-1 in ZIP 79976 ---
#   -> Retrieved 0 records. Total skip count: 0
#
# --- Searching for NPI-2 in ZIP 79978 ---
#   -> Retrieved 0 records. Total skip count: 0
#
# --- Searching for NPI-1 in ZIP 79978 ---
#   -> Retrieved 0 records. Total skip count: 0
#
# --- Searching for NPI-2 in ZIP 79980 ---
#   -> Retrieved 0 records. Total skip count: 0
#
# --- Searching for NPI-1 in ZIP 79980 ---
#   -> Retrieved 0 records. Total skip count: 0
#
# --- Searching for NPI-2 in ZIP 79990 ---
#   -> Retrieved 0 records. Total skip count: 0
#
# --- Searching for NPI-1 in ZIP 79990 ---
#   -> Retrieved 0 records. Total skip count: 0
#
# --- Searching for NPI-2 in ZIP 79995 ---
#   -> Retrieved 33 records. Total skip count: 0
#
# --- Searching for NPI-1 in ZIP 79995 ---
#   -> Retrieved 91 records. Total skip count: 0
#
# --- Searching for NPI-2 in ZIP 79996 ---
#   -> Retrieved 17 records. Total skip count: 0
#
# --- Searching for NPI-1 in ZIP 79996 ---
#   -> Retrieved 44 records. Total skip count: 0
#
# --- Searching for NPI-2 in ZIP 79997 ---
#   -> Retrieved 16 records. Total skip count: 0
#
# --- Searching for NPI-1 in ZIP 79997 ---
#   -> Retrieved 14 records. Total skip count: 0
#
# --- Searching for NPI-2 in ZIP 79998 ---
#   -> Retrieved 0 records. Total skip count: 0
#
# --- Searching for NPI-1 in ZIP 79998 ---
#   -> Retrieved 0 records. Total skip count: 0
#
# --- Searching for NPI-2 in ZIP 79999 ---
#   -> Retrieved 0 records. Total skip count: 0
#
# --- Searching for NPI-1 in ZIP 79999 ---
#   -> Retrieved 0 records. Total skip count: 0
#
# --- Cleaning and Deduplicating Data ---
# Total Unique Facilities: 3987
# Total Unique Doctors: 11110
#
# --- FINAL LINKED NPI DIRECTORY SUMMARY ---
# ✅ Total unique doctor records processed and linked: 24188
# File saved successfully as 'el_paso_linked_directory.csv'
#
# --- Sample Linked Records (Showing Doctor to Facility Match) ---
#                         Name           Primary_Taxonomy  \
# 0       BARBARA ABALOS, BCBA           Behavior Analyst
# 1          SAMUEL ABOUD, RPh                 Pharmacist
# 2  MOHAMMAD ABOUKHADIJA, DDS  Dentist, General Practice
# 3      ISABEL ACOSTA VALDES,  Dentist, General Practice
# 4           JENNIFER ADCOCK,           Behavior Analyst
# 5           JENNIFER ADCOCK,           Behavior Analyst
# 6           JESSICA AGUILAR,        Behavior Technician
# 7             KAREN AGUILAR,        Behavior Technician
# 8            FRIDA AGUILERA,        Behavior Technician
# 9      ADRIANA AGUIRRE, BCBA           Behavior Analyst
#
#                             Facility_Name         Facility_Address
# 0                    Independent/Unlinked                      NaN
# 1                    Independent/Unlinked                      NaN
# 2                    Independent/Unlinked                      NaN
# 3                    Independent/Unlinked                      NaN
# 4                               BLISS ABA  221 N KANSAS ST STE 700
# 5               ILLUMINATED DIRECTION LLC  221 N KANSAS ST STE 700
# 6         BEHAVIOR CHANGE INSTITUTE, LLC.              1408 8TH ST
# 7                    Independent/Unlinked                      NaN
# 8  POSITIVE BEHAVIOR SUPPORTS CORPORATION        7108 S KANNER HWY
# 9                    Independent/Unlinked                      NaN

# %%
pip install googlemaps
# Out:
# Collecting googlemaps
#   Downloading googlemaps-4.10.0.tar.gz (33 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: requests<3.0,>=2.20.0 in /usr/local/lib/python3.12/dist-packages (from googlemaps) (2.32.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0,>=2.20.0->googlemaps) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3.0,>=2.20.0->googlemaps) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3.0,>=2.20.0->googlemaps) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3.0,>=2.20.0->googlemaps) (2025.11.12)
# Building wheels for collected packages: googlemaps
#   Building wheel for googlemaps (setup.py) ... done
#   Created wheel for googlemaps: filename=googlemaps-4.10.0-py3-none-any.whl size=40714 sha256=e0f68174b986dab3e3e10b1594815e612fb2539aedecfe325a419da2c27581a7
#   Stored in directory: /root/.cache/pip/wheels/4c/6a/a7/bbc6f5c200032025ee655deb5e163ce8594fa05e67d973aad6
# Successfully built googlemaps
# Installing collected packages: googlemaps
# Successfully installed googlemaps-4.10.0

# %%
print("Google Maps package installed successfully.")

# %%
import googlemaps
import pandas as pd
import time

# --- CONFIGURATION ---
# Replace with your actual Google Cloud API Key
API_KEY = "AIzaSyBgI_vaGTppsp-P_UpLPOdRSDKAYI1uw8E"

# Search terms to ensure we catch both facilities and private practices
SEARCH_QUERIES = ["clinic", "doctor", "medical center", "urgent care"]

EL_PASO_ZIPS = [
    "79901", "79902", "79903", "79904", "79905", "79906", "79907",
    "79908", "79910", "79911", "79912", "79913", "79914", "79915",
    "79916", "79917", "79918", "79920", "79922", "79923", "79924",
    "79925", "79926", "79927", "79928", "79929", "79930", "79931",
    "79932", "79934", "79935", "79936", "79937", "79938", "79940",
    "79941", "79942", "79943", "79944", "79945", "79946", "79947",
    "79948", "79949", "79950", "79951", "79952", "79953", "79954",
    "79955", "79958", "79960", "79961", "79968", "79976", "79978",
    "79980", "79990", "79995", "79996", "79997", "79998", "79999"
]

# Initialize Client
gmaps = googlemaps.Client(key=API_KEY)

def get_places_in_zip(zip_code, queries):
    """
    Searches for multiple terms in a ZIP code and collects Place IDs.
    Returns a dictionary of unique places {place_id: basic_info_dict}
    """
    found_places = {}

    for query in queries:
        search_term = f"{query} in {zip_code}, El Paso, TX"
        print(f"  🔍 Searching for: '{search_term}'...")

        # Initial Request
        try:
            response = gmaps.places(query=search_term)

            while True:
                results = response.get('results', [])

                for place in results:
                    pid = place.get('place_id')
                    # Store basic info if we haven't seen this Place ID yet
                    if pid and pid not in found_places:
                        found_places[pid] = {
                            'Place_ID': pid,
                            'Name': place.get('name'),
                            'Address': place.get('formatted_address'),
                            'Zip_Searched': zip_code,
                            'Type_Found': query # helps understand if it was found as a "doctor" or "clinic"
                        }

                # Handle Pagination (Get next 20 results if available)
                if 'next_page_token' in response:
                    time.sleep(2) # Mandatory delay for token to become valid
                    response = gmaps.places(query=search_term, page_token=response['next_page_token'])
                else:
                    break

        except Exception as e:
            print(f"    ⚠️ Error searching '{search_term}': {e}")

    return found_places

def fetch_details(place_id):
    """
    Fetches specific contact details (Phone, Website) for a Place ID.
    This consumes a 'Place Details' quota unit.
    """
    try:
        # We only request specific fields to manage data payload, though cost is based on "SKU"
        details = gmaps.place(place_id=place_id, fields=['formatted_phone_number', 'website'])
        result = details.get('result', {})
        return {
            'Phone': result.get('formatted_phone_number', 'N/A'),
            'Website': result.get('website', 'N/A')
        }
    except Exception as e:
        print(f"    ⚠️ Error fetching details for ID {place_id}: {e}")
        return {'Phone': 'Error', 'Website': 'Error'}

def run_google_extraction():
    all_unique_places = {}

    # --- PHASE 1: SEARCH & DISCOVERY ---
    print("\n--- PHASE 1: Discovering Places by ZIP Code ---")
    for zip_code in EL_PASO_ZIPS:
        places_in_zip = get_places_in_zip(zip_code, SEARCH_QUERIES)

        # Add to master list (dictionaries overwrite duplicates automatically)
        for pid, data in places_in_zip.items():
            if pid not in all_unique_places:
                all_unique_places[pid] = data

        print(f"  ✅ ZIP {zip_code} finished. Total unique places so far: {len(all_unique_places)}")
        time.sleep(1) # Be nice to the API

    # --- PHASE 2: ENRICHMENT (Fetching Phones) ---
    print(f"\n--- PHASE 2: Fetching Phone Numbers for {len(all_unique_places)} Places ---")
    print("This may take time and consumes API Detail quotas...")

    final_data = []
    count = 0

    for pid, place_data in all_unique_places.items():
        count += 1
        if count % 50 == 0:
            print(f"  Processing {count}/{len(all_unique_places)}...")

        # Fetch the missing details
        details = fetch_details(pid)

        # Merge dictionaries
        full_record = {**place_data, **details}
        final_data.append(full_record)

        # Rate limiting to prevent errors
        time.sleep(0.1)

    return pd.DataFrame(final_data)

# --- EXECUTION ---
if __name__ == "__main__":
    df = run_google_extraction()

    if not df.empty:
        filename = 'el_paso_google_places_full.csv'
        df.to_csv(filename, index=False)
        print(f"\n🎉 Success! Extracted {len(df)} records to '{filename}'")
        print(df[['Name', 'Phone', 'Address']].head())
    else:
        print("\n❌ No data found. Check API Key and Quotas.")
# Out:
# --- PHASE 1: Discovering Places by ZIP Code ---
#   🔍 Searching for: 'clinic in 79901, El Paso, TX'...
#   🔍 Searching for: 'doctor in 79901, El Paso, TX'...
#   🔍 Searching for: 'medical center in 79901, El Paso, TX'...
#   🔍 Searching for: 'urgent care in 79901, El Paso, TX'...
#   ✅ ZIP 79901 finished. Total unique places so far: 147
#   🔍 Searching for: 'clinic in 79902, El Paso, TX'...
#   🔍 Searching for: 'doctor in 79902, El Paso, TX'...
#   🔍 Searching for: 'medical center in 79902, El Paso, TX'...
#   🔍 Searching for: 'urgent care in 79902, El Paso, TX'...
#   ✅ ZIP 79902 finished. Total unique places so far: 199
#   🔍 Searching for: 'clinic in 79903, El Paso, TX'...
#   🔍 Searching for: 'doctor in 79903, El Paso, TX'...
#   🔍 Searching for: 'medical center in 79903, El Paso, TX'...
#   🔍 Searching for: 'urgent care in 79903, El Paso, TX'...
#   ✅ ZIP 79903 finished. Total unique places so far: 277
#   🔍 Searching for: 'clinic in 79904, El Paso, TX'...
#   🔍 Searching for: 'doctor in 79904, El Paso, TX'...
#   🔍 Searching for: 'medical center in 79904, El Paso, TX'...
#   🔍 Searching for: 'urgent care in 79904, El Paso, TX'...
#   ✅ ZIP 79904 finished. Total unique places so far: 346
#   🔍 Searching for: 'clinic in 79905, El Paso, TX'...
#   🔍 Searching for: 'doctor in 79905, El Paso, TX'...
#   🔍 Searching for: 'medical center in 79905, El Paso, TX'...
#   🔍 Searching for: 'urgent care in 79905, El Paso, TX'...
#   ✅ ZIP 79905 finished. Total unique places so far: 393
#   🔍 Searching for: 'clinic in 79906, El Paso, TX'...
#   🔍 Searching for: 'doctor in 79906, El Paso, TX'...
#   🔍 Searching for: 'medical center in 79906, El Paso, TX'...
#   🔍 Searching for: 'urgent care in 79906, El Paso, TX'...
#   ✅ ZIP 79906 finished. Total unique places so far: 417
#   🔍 Searching for: 'clinic in 79907, El Paso, TX'...
#   🔍 Searching for: 'doctor in 79907, El Paso, TX'...
#   🔍 Searching for: 'medical center in 79907, El Paso, TX'...
#   🔍 Searching for: 'urgent care in 79907, El Paso, TX'...
#   ✅ ZIP 79907 finished. Total unique places so far: 482
#   🔍 Searching for: 'clinic in 79908, El Paso, TX'...
#   🔍 Searching for: 'doctor in 79908, El Paso, TX'...
#   🔍 Searching for: 'medical center in 79908, El Paso, TX'...
#   🔍 Searching for: 'urgent care in 79908, El Paso, TX'...
#   ✅ ZIP 79908 finished. Total unique places so far: 513
#   🔍 Searching for: 'clinic in 79910, El Paso, TX'...
#   🔍 Searching for: 'doctor in 79910, El Paso, TX'...
#   🔍 Searching for: 'medical center in 79910, El Paso, TX'...
#   🔍 Searching for: 'urgent care in 79910, El Paso, TX'...
#   ✅ ZIP 79910 finished. Total unique places so far: 541
#   🔍 Searching for: 'clinic in 79911, El Paso, TX'...
#   🔍 Searching for: 'doctor in 79911, El Paso, TX'...
#   🔍 Searching for: 'medical center in 79911, El Paso, TX'...
#   🔍 Searching for: 'urgent care in 79911, El Paso, TX'...
#   ✅ ZIP 79911 finished. Total unique places so far: 609
#   🔍 Searching for: 'clinic in 79912, El Paso, TX'...
#   🔍 Searching for: 'doctor in 79912, El Paso, TX'...
#   🔍 Searching for: 'medical center in 79912, El Paso, TX'...
#   🔍 Searching for: 'urgent care in 79912, El Paso, TX'...
#   ✅ ZIP 79912 finished. Total unique places so far: 651
#   🔍 Searching for: 'clinic in 79913, El Paso, TX'...
#   🔍 Searching for: 'doctor in 79913, El Paso, TX'...
#   🔍 Searching for: 'medical center in 79913, El Paso, TX'...
#   🔍 Searching for: 'urgent care in 79913, El Paso, TX'...
#   ✅ ZIP 79913 finished. Total unique places so far: 682
#   🔍 Searching for: 'clinic in 79914, El Paso, TX'...
#   🔍 Searching for: 'doctor in 79914, El Paso, TX'...
#   🔍 Searching for: 'medical center in 79914, El Paso, TX'...
#   🔍 Searching for: 'urgent care in 79914, El Paso, TX'...
#   ✅ ZIP 79914 finished. Total unique places so far: 685
#   🔍 Searching for: 'clinic in 79915, El Paso, TX'...
#   🔍 Searching for: 'doctor in 79915, El Paso, TX'...
#   🔍 Searching for: 'medical center in 79915, El Paso, TX'...
#   🔍 Searching for: 'urgent care in 79915, El Paso, TX'...
#   ✅ ZIP 79915 finished. Total unique places so far: 717
#   🔍 Searching for: 'clinic in 79916, El Paso, TX'...
#   🔍 Searching for: 'doctor in 79916, El Paso, TX'...
#   🔍 Searching for: 'medical center in 79916, El Paso, TX'...
#   🔍 Searching for: 'urgent care in 79916, El Paso, TX'...
#   ✅ ZIP 79916 finished. Total unique places so far: 738
#   🔍 Searching for: 'clinic in 79917, El Paso, TX'...
#   🔍 Searching for: 'doctor in 79917, El Paso, TX'...
#   🔍 Searching for: 'medical center in 79917, El Paso, TX'...
#   🔍 Searching for: 'urgent care in 79917, El Paso, TX'...
#   ✅ ZIP 79917 finished. Total unique places so far: 741
#   🔍 Searching for: 'clinic in 79918, El Paso, TX'...
#   🔍 Searching for: 'doctor in 79918, El Paso, TX'...
#   🔍 Searching for: 'medical center in 79918, El Paso, TX'...
#   🔍 Searching for: 'urgent care in 79918, El Paso, TX'...
#   ✅ ZIP 79918 finished. Total unique places so far: 746
#   🔍 Searching for: 'clinic in 79920, El Paso, TX'...
#   🔍 Searching for: 'doctor in 79920, El Paso, TX'...
#   🔍 Searching for: 'medical center in 79920, El Paso, TX'...
#   🔍 Searching for: 'urgent care in 79920, El Paso, TX'...
#   ✅ ZIP 79920 finished. Total unique places so far: 755
#   🔍 Searching for: 'clinic in 79922, El Paso, TX'...
#   🔍 Searching for: 'doctor in 79922, El Paso, TX'...
#   🔍 Searching for: 'medical center in 79922, El Paso, TX'...
#   🔍 Searching for: 'urgent care in 79922, El Paso, TX'...
#   ✅ ZIP 79922 finished. Total unique places so far: 775
#   🔍 Searching for: 'clinic in 79923, El Paso, TX'...
#   🔍 Searching for: 'doctor in 79923, El Paso, TX'...
#   🔍 Searching for: 'medical center in 79923, El Paso, TX'...
#   🔍 Searching for: 'urgent care in 79923, El Paso, TX'...
#   ✅ ZIP 79923 finished. Total unique places so far: 797
#   🔍 Searching for: 'clinic in 79924, El Paso, TX'...
#   🔍 Searching for: 'doctor in 79924, El Paso, TX'...
#   🔍 Searching for: 'medical center in 79924, El Paso, TX'...
#   🔍 Searching for: 'urgent care in 79924, El Paso, TX'...
#   ✅ ZIP 79924 finished. Total unique places so far: 823
#   🔍 Searching for: 'clinic in 79925, El Paso, TX'...
#   🔍 Searching for: 'doctor in 79925, El Paso, TX'...
#   🔍 Searching for: 'medical center in 79925, El Paso, TX'...
#   🔍 Searching for: 'urgent care in 79925, El Paso, TX'...
#   ✅ ZIP 79925 finished. Total unique places so far: 840
#   🔍 Searching for: 'clinic in 79926, El Paso, TX'...
#   🔍 Searching for: 'doctor in 79926, El Paso, TX'...
#   🔍 Searching for: 'medical center in 79926, El Paso, TX'...
#   🔍 Searching for: 'urgent care in 79926, El Paso, TX'...
#   ✅ ZIP 79926 finished. Total unique places so far: 848
#   🔍 Searching for: 'clinic in 79927, El Paso, TX'...
#   🔍 Searching for: 'doctor in 79927, El Paso, TX'...
#   🔍 Searching for: 'medical center in 79927, El Paso, TX'...
#   🔍 Searching for: 'urgent care in 79927, El Paso, TX'...
#   ✅ ZIP 79927 finished. Total unique places so far: 875
#   🔍 Searching for: 'clinic in 79928, El Paso, TX'...
#   🔍 Searching for: 'doctor in 79928, El Paso, TX'...
#   🔍 Searching for: 'medical center in 79928, El Paso, TX'...
#   🔍 Searching for: 'urgent care in 79928, El Paso, TX'...
#   ✅ ZIP 79928 finished. Total unique places so far: 900
#   🔍 Searching for: 'clinic in 79929, El Paso, TX'...
#   🔍 Searching for: 'doctor in 79929, El Paso, TX'...
#   🔍 Searching for: 'medical center in 79929, El Paso, TX'...
#   🔍 Searching for: 'urgent care in 79929, El Paso, TX'...
#   ✅ ZIP 79929 finished. Total unique places so far: 900
#   🔍 Searching for: 'clinic in 79930, El Paso, TX'...
#   🔍 Searching for: 'doctor in 79930, El Paso, TX'...
#   🔍 Searching for: 'medical center in 79930, El Paso, TX'...
#   🔍 Searching for: 'urgent care in 79930, El Paso, TX'...
#   ✅ ZIP 79930 finished. Total unique places so far: 911
#   🔍 Searching for: 'clinic in 79931, El Paso, TX'...
#   🔍 Searching for: 'doctor in 79931, El Paso, TX'...
#   🔍 Searching for: 'medical center in 79931, El Paso, TX'...
#   🔍 Searching for: 'urgent care in 79931, El Paso, TX'...
#   ✅ ZIP 79931 finished. Total unique places so far: 913
#   🔍 Searching for: 'clinic in 79932, El Paso, TX'...
#   🔍 Searching for: 'doctor in 79932, El Paso, TX'...
#   🔍 Searching for: 'medical center in 79932, El Paso, TX'...
#   🔍 Searching for: 'urgent care in 79932, El Paso, TX'...
#   ✅ ZIP 79932 finished. Total unique places so far: 920
#   🔍 Searching for: 'clinic in 79934, El Paso, TX'...
#   🔍 Searching for: 'doctor in 79934, El Paso, TX'...
#   🔍 Searching for: 'medical center in 79934, El Paso, TX'...
#   🔍 Searching for: 'urgent care in 79934, El Paso, TX'...
#   ✅ ZIP 79934 finished. Total unique places so far: 931
#   🔍 Searching for: 'clinic in 79935, El Paso, TX'...
#   🔍 Searching for: 'doctor in 79935, El Paso, TX'...
#   🔍 Searching for: 'medical center in 79935, El Paso, TX'...
#   🔍 Searching for: 'urgent care in 79935, El Paso, TX'...
#   ✅ ZIP 79935 finished. Total unique places so far: 963
#   🔍 Searching for: 'clinic in 79936, El Paso, TX'...
#   🔍 Searching for: 'doctor in 79936, El Paso, TX'...
#   🔍 Searching for: 'medical center in 79936, El Paso, TX'...
#   🔍 Searching for: 'urgent care in 79936, El Paso, TX'...
#   ✅ ZIP 79936 finished. Total unique places so far: 987
#   🔍 Searching for: 'clinic in 79937, El Paso, TX'...
#   🔍 Searching for: 'doctor in 79937, El Paso, TX'...
#   🔍 Searching for: 'medical center in 79937, El Paso, TX'...
#   🔍 Searching for: 'urgent care in 79937, El Paso, TX'...
#   ✅ ZIP 79937 finished. Total unique places so far: 991
#   🔍 Searching for: 'clinic in 79938, El Paso, TX'...
#   🔍 Searching for: 'doctor in 79938, El Paso, TX'...
#   🔍 Searching for: 'medical center in 79938, El Paso, TX'...
#   🔍 Searching for: 'urgent care in 79938, El Paso, TX'...
#   ✅ ZIP 79938 finished. Total unique places so far: 1003
#   🔍 Searching for: 'clinic in 79940, El Paso, TX'...
#   🔍 Searching for: 'doctor in 79940, El Paso, TX'...
#   🔍 Searching for: 'medical center in 79940, El Paso, TX'...
#   🔍 Searching for: 'urgent care in 79940, El Paso, TX'...
#   ✅ ZIP 79940 finished. Total unique places so far: 1008
#   🔍 Searching for: 'clinic in 79941, El Paso, TX'...
#   🔍 Searching for: 'doctor in 79941, El Paso, TX'...
#   🔍 Searching for: 'medical center in 79941, El Paso, TX'...
#   🔍 Searching for: 'urgent care in 79941, El Paso, TX'...
#   ✅ ZIP 79941 finished. Total unique places so far: 1018
#   🔍 Searching for: 'clinic in 79942, El Paso, TX'...
#   🔍 Searching for: 'doctor in 79942, El Paso, TX'...
#   🔍 Searching for: 'medical center in 79942, El Paso, TX'...
#   🔍 Searching for: 'urgent care in 79942, El Paso, TX'...
#   ✅ ZIP 79942 finished. Total unique places so far: 1023
#   🔍 Searching for: 'clinic in 79943, El Paso, TX'...
#   🔍 Searching for: 'doctor in 79943, El Paso, TX'...
#   🔍 Searching for: 'medical center in 79943, El Paso, TX'...
#   🔍 Searching for: 'urgent care in 79943, El Paso, TX'...
#   ✅ ZIP 79943 finished. Total unique places so far: 1023
#   🔍 Searching for: 'clinic in 79944, El Paso, TX'...
#   🔍 Searching for: 'doctor in 79944, El Paso, TX'...
#   🔍 Searching for: 'medical center in 79944, El Paso, TX'...
#   🔍 Searching for: 'urgent care in 79944, El Paso, TX'...
#   ✅ ZIP 79944 finished. Total unique places so far: 1024
#   🔍 Searching for: 'clinic in 79945, El Paso, TX'...
#   🔍 Searching for: 'doctor in 79945, El Paso, TX'...
#   🔍 Searching for: 'medical center in 79945, El Paso, TX'...
#   🔍 Searching for: 'urgent care in 79945, El Paso, TX'...
#   ✅ ZIP 79945 finished. Total unique places so far: 1025
#   🔍 Searching for: 'clinic in 79946, El Paso, TX'...
#   🔍 Searching for: 'doctor in 79946, El Paso, TX'...
#   🔍 Searching for: 'medical center in 79946, El Paso, TX'...
#   🔍 Searching for: 'urgent care in 79946, El Paso, TX'...
#   ✅ ZIP 79946 finished. Total unique places so far: 1031
#   🔍 Searching for: 'clinic in 79947, El Paso, TX'...
#   🔍 Searching for: 'doctor in 79947, El Paso, TX'...
#   🔍 Searching for: 'medical center in 79947, El Paso, TX'...
#   🔍 Searching for: 'urgent care in 79947, El Paso, TX'...
#   ✅ ZIP 79947 finished. Total unique places so far: 1033
#   🔍 Searching for: 'clinic in 79948, El Paso, TX'...
#   🔍 Searching for: 'doctor in 79948, El Paso, TX'...
#   🔍 Searching for: 'medical center in 79948, El Paso, TX'...
#   🔍 Searching for: 'urgent care in 79948, El Paso, TX'...
#   ✅ ZIP 79948 finished. Total unique places so far: 1034
#   🔍 Searching for: 'clinic in 79949, El Paso, TX'...
#   🔍 Searching for: 'doctor in 79949, El Paso, TX'...
#   🔍 Searching for: 'medical center in 79949, El Paso, TX'...
#   🔍 Searching for: 'urgent care in 79949, El Paso, TX'...
#   ✅ ZIP 79949 finished. Total unique places so far: 1036
#   🔍 Searching for: 'clinic in 79950, El Paso, TX'...
#   🔍 Searching for: 'doctor in 79950, El Paso, TX'...
#   🔍 Searching for: 'medical center in 79950, El Paso, TX'...
#   🔍 Searching for: 'urgent care in 79950, El Paso, TX'...
#   ✅ ZIP 79950 finished. Total unique places so far: 1038
#   🔍 Searching for: 'clinic in 79951, El Paso, TX'...
#   🔍 Searching for: 'doctor in 79951, El Paso, TX'...
#   🔍 Searching for: 'medical center in 79951, El Paso, TX'...
#   🔍 Searching for: 'urgent care in 79951, El Paso, TX'...
#   ✅ ZIP 79951 finished. Total unique places so far: 1039
#   🔍 Searching for: 'clinic in 79952, El Paso, TX'...
#   🔍 Searching for: 'doctor in 79952, El Paso, TX'...
#   🔍 Searching for: 'medical center in 79952, El Paso, TX'...
#   🔍 Searching for: 'urgent care in 79952, El Paso, TX'...
#   ✅ ZIP 79952 finished. Total unique places so far: 1040
#   🔍 Searching for: 'clinic in 79953, El Paso, TX'...
#   🔍 Searching for: 'doctor in 79953, El Paso, TX'...
#   🔍 Searching for: 'medical center in 79953, El Paso, TX'...
#   🔍 Searching for: 'urgent care in 79953, El Paso, TX'...
#   ✅ ZIP 79953 finished. Total unique places so far: 1043
#   🔍 Searching for: 'clinic in 79954, El Paso, TX'...
#   🔍 Searching for: 'doctor in 79954, El Paso, TX'...
#   🔍 Searching for: 'medical center in 79954, El Paso, TX'...
#   🔍 Searching for: 'urgent care in 79954, El Paso, TX'...
#   ✅ ZIP 79954 finished. Total unique places so far: 1047
#   🔍 Searching for: 'clinic in 79955, El Paso, TX'...
#   🔍 Searching for: 'doctor in 79955, El Paso, TX'...
#   🔍 Searching for: 'medical center in 79955, El Paso, TX'...
#   🔍 Searching for: 'urgent care in 79955, El Paso, TX'...
#   ✅ ZIP 79955 finished. Total unique places so far: 1047
#   🔍 Searching for: 'clinic in 79958, El Paso, TX'...
#   🔍 Searching for: 'doctor in 79958, El Paso, TX'...
#   🔍 Searching for: 'medical center in 79958, El Paso, TX'...
#   🔍 Searching for: 'urgent care in 79958, El Paso, TX'...
#   ✅ ZIP 79958 finished. Total unique places so far: 1049
#   🔍 Searching for: 'clinic in 79960, El Paso, TX'...
#   🔍 Searching for: 'doctor in 79960, El Paso, TX'...
#   🔍 Searching for: 'medical center in 79960, El Paso, TX'...
#   🔍 Searching for: 'urgent care in 79960, El Paso, TX'...
#   ✅ ZIP 79960 finished. Total unique places so far: 1049
#   🔍 Searching for: 'clinic in 79961, El Paso, TX'...
#   🔍 Searching for: 'doctor in 79961, El Paso, TX'...
#   🔍 Searching for: 'medical center in 79961, El Paso, TX'...
#   🔍 Searching for: 'urgent care in 79961, El Paso, TX'...
#   ✅ ZIP 79961 finished. Total unique places so far: 1050
#   🔍 Searching for: 'clinic in 79968, El Paso, TX'...
#   🔍 Searching for: 'doctor in 79968, El Paso, TX'...
#   🔍 Searching for: 'medical center in 79968, El Paso, TX'...
#   🔍 Searching for: 'urgent care in 79968, El Paso, TX'...
#   ✅ ZIP 79968 finished. Total unique places so far: 1055
#   🔍 Searching for: 'clinic in 79976, El Paso, TX'...
#   🔍 Searching for: 'doctor in 79976, El Paso, TX'...
#   🔍 Searching for: 'medical center in 79976, El Paso, TX'...
#   🔍 Searching for: 'urgent care in 79976, El Paso, TX'...
#   ✅ ZIP 79976 finished. Total unique places so far: 1055
#   🔍 Searching for: 'clinic in 79978, El Paso, TX'...
#   🔍 Searching for: 'doctor in 79978, El Paso, TX'...
#   🔍 Searching for: 'medical center in 79978, El Paso, TX'...
#   🔍 Searching for: 'urgent care in 79978, El Paso, TX'...
#   ✅ ZIP 79978 finished. Total unique places so far: 1055
#   🔍 Searching for: 'clinic in 79980, El Paso, TX'...
#   🔍 Searching for: 'doctor in 79980, El Paso, TX'...
#   🔍 Searching for: 'medical center in 79980, El Paso, TX'...
#   🔍 Searching for: 'urgent care in 79980, El Paso, TX'...
#   ✅ ZIP 79980 finished. Total unique places so far: 1058
#   🔍 Searching for: 'clinic in 79990, El Paso, TX'...
#   🔍 Searching for: 'doctor in 79990, El Paso, TX'...
#   🔍 Searching for: 'medical center in 79990, El Paso, TX'...
#   🔍 Searching for: 'urgent care in 79990, El Paso, TX'...
#   ✅ ZIP 79990 finished. Total unique places so far: 1066
#   🔍 Searching for: 'clinic in 79995, El Paso, TX'...
#   🔍 Searching for: 'doctor in 79995, El Paso, TX'...
#   🔍 Searching for: 'medical center in 79995, El Paso, TX'...
#   🔍 Searching for: 'urgent care in 79995, El Paso, TX'...
#   ✅ ZIP 79995 finished. Total unique places so far: 1073
#   🔍 Searching for: 'clinic in 79996, El Paso, TX'...
#   🔍 Searching for: 'doctor in 79996, El Paso, TX'...
#   🔍 Searching for: 'medical center in 79996, El Paso, TX'...
#   🔍 Searching for: 'urgent care in 79996, El Paso, TX'...
#   ✅ ZIP 79996 finished. Total unique places so far: 1084
#   🔍 Searching for: 'clinic in 79997, El Paso, TX'...
#   🔍 Searching for: 'doctor in 79997, El Paso, TX'...
#   🔍 Searching for: 'medical center in 79997, El Paso, TX'...
#   🔍 Searching for: 'urgent care in 79997, El Paso, TX'...
#   ✅ ZIP 79997 finished. Total unique places so far: 1085
#   🔍 Searching for: 'clinic in 79998, El Paso, TX'...
#   🔍 Searching for: 'doctor in 79998, El Paso, TX'...
#   🔍 Searching for: 'medical center in 79998, El Paso, TX'...
#   🔍 Searching for: 'urgent care in 79998, El Paso, TX'...
#   ✅ ZIP 79998 finished. Total unique places so far: 1085
#   🔍 Searching for: 'clinic in 79999, El Paso, TX'...
#   🔍 Searching for: 'doctor in 79999, El Paso, TX'...
#   🔍 Searching for: 'medical center in 79999, El Paso, TX'...
#   🔍 Searching for: 'urgent care in 79999, El Paso, TX'...
#   ✅ ZIP 79999 finished. Total unique places so far: 1087
#
# --- PHASE 2: Fetching Phone Numbers for 1087 Places ---
# This may take time and consumes API Detail quotas...
#   Processing 50/1087...
#   Processing 100/1087...
#   Processing 150/1087...
#   Processing 200/1087...
#   Processing 250/1087...
#   Processing 300/1087...
#   Processing 350/1087...
#   Processing 400/1087...
#   Processing 450/1087...
#   Processing 500/1087...
#   Processing 550/1087...
#   Processing 600/1087...
#   Processing 650/1087...
#   Processing 700/1087...
#   Processing 750/1087...
#   Processing 800/1087...
#   Processing 850/1087...
#   Processing 900/1087...
#   Processing 950/1087...
#   Processing 1000/1087...
#   Processing 1050/1087...
#
# 🎉 Success! Extracted 1087 records to 'el_paso_google_places_full.csv'
#                                    Name           Phone  \
# 0  Centro De Salud Familiar La Fe, Inc.  (915) 545-4550
# 1          Southwest Urgent Care Center  (915) 910-6595
# 2            La Fe Yandell Adult Clinic  (915) 545-7205
# 3                       HOMELESS CLINIC  (915) 351-8972
# 4                  El Paso Primary Care  (915) 500-6080
#
#                                              Address
# 0   700 S Ochoa St, El Paso, TX 79901, United States
# 1   2030 N Mesa St, El Paso, TX 79902, United States
# 2   823 Yandell Dr, El Paso, TX 79902, United States
# 3  1208 Myrtle Ave, El Paso, TX 79901, United States
# 4   4545 N Mesa St, El Paso, TX 79912, United States

# %%
import pandas as pd
df = pd.read_csv('/content/el_paso_google_places_full.csv')

# %%
df.head()
# Out:
#                       Place_ID                                  Name  \
# 0  ChIJ_-5EpxtZ54YRr97QSRfNxiA  Centro De Salud Familiar La Fe, Inc.
# 1  ChIJGa7fm1BY54YRgzqOv-HEEnU          Southwest Urgent Care Center
# 2  ChIJ20hSeABZ54YRtXxOFZR8RPI            La Fe Yandell Adult Clinic
# 3  ChIJ8dEvGAZZ54YRFq52hEh7bxY                       HOMELESS CLINIC
# 4  ChIJF4xEyJRZ54YRtAGakwLBqxI                  El Paso Primary Care
#
#                                              Address  Zip_Searched Type_Found  \
# 0   700 S Ochoa St, El Paso, TX 79901, United States         79901     clinic
# 1   2030 N Mesa St, El Paso, TX 79902, United States         79901     clinic
# 2   823 Yandell Dr, El Paso, TX 79902, United States         79901     clinic
# 3  1208 Myrtle Ave, El Paso, TX 79901, United States         79901     clinic
# 4   4545 N Mesa St, El Paso, TX 79912, United States         79901     clinic
#
#             Phone                                    Website
# 0  (915) 545-4550                        http://lafe-ep.org/
# 1  (915) 910-6595       https://www.southwesturgentcare.net/
# 2  (915) 545-7205  https://lafe-ep.org/yandell-adult-clinic/
# 3  (915) 351-8972                                        NaN
# 4  (915) 500-6080         https://www.elpasoprimarycare.com/

# %%
import pandas as pd
import re

# Load the data generated by your previous script
# df = pd.read_csv('el_paso_google_places_full.csv')
# If running in same script, just use the 'df' you already have.

# --- STEP 1: DISTINGUISH DOCTORS FROM CLINICS ---
def classify_entity(row):
    name = str(row['Name']).upper()
    # Simple heuristics to identify individuals vs businesses
    if re.search(r'\b(DR\.|MD|DO|Dr\.|DDS|DMD|OD|PHD)\b', name):
        return 'Doctor'
    return 'Clinic'

df['Category'] = df.apply(classify_entity, axis=1)

# --- STEP 2: NORMALIZE ADDRESSES FOR MATCHING ---
# We make a 'Match_Key' because "123 Main St." and "123 MAIN ST" should match.
def clean_address(addr):
    if pd.isna(addr): return ""
    # Lowercase, remove punctuation, remove extra spaces
    addr = str(addr).lower().strip()
    addr = re.sub(r'[^\w\s]', '', addr)
    return addr

df['Match_Key'] = df['Address'].apply(clean_address)

# --- STEP 3: GROUP BY ADDRESS & ASSIGN ---
# We group the data by our cleaned address
grouped = df.groupby('Match_Key')

linked_data = []

for address_key, group_df in grouped:
    # Get all clinics at this address
    clinics = group_df[group_df['Category'] == 'Clinic']['Name'].unique().tolist()
    # Get all doctors at this address
    doctors = group_df[group_df['Category'] == 'Doctor']['Name'].unique().tolist()

    # Grab the official formatted address and phone from the first record found
    official_address = group_df.iloc[0]['Address']
    official_phone = group_df.iloc[0]['Phone']

    if clinics:
        # SCENARIO A: Found a Clinic (and possibly doctors)
        for clinic_name in clinics:
            linked_data.append({
                'Clinic_Name': clinic_name,
                'Associated_Doctors': ", ".join(doctors) if doctors else "No Individual Doctors Listed",
                'Address': official_address,
                'Phone': official_phone,
                'Type': 'Medical Facility'
            })
    elif doctors:
        # SCENARIO B: Found Doctors but NO Clinic Name (likely a solo practice)
        # We create a row for the doctor acting as the clinic
        linked_data.append({
            'Clinic_Name': "Solo Practice / Independent",
            'Associated_Doctors': ", ".join(doctors),
            'Address': official_address,
            'Phone': official_phone,
            'Type': 'Private Practice'
        })

# %%
# --- STEP 4: FINAL OUTPUT ---
final_mapped_df = pd.DataFrame(linked_data)

# %%
# Reorder columns for readability
final_mapped_df = final_mapped_df[['Clinic_Name', 'Associated_Doctors', 'Phone', 'Address', 'Type']]

# %%
final_mapped_df.head(15)
# Out:
#                                           Clinic_Name  \
# 0                                     Cardinal Health
# 1   La Clinica De Familia - Santa Teresa School Ba...
# 2                         Solo Practice / Independent
# 3                             Hopewell Medical Center
# 4                                 Dr. Olufemi Aduroja
# 5                                      Macias Jesus A
# 6    Advanced Center for Women's Health at Providence
# 7           Dr. Carlos Viesca - Border Pain Institute
# 8                                  Sylvia Arreola, RN
# 9                         Urgent Care Home Health Inc
# 10                            Las Ventanas de Socorro
# 11            Village Medical at Walgreens - Rushfair
# 12                              Dora M. Carcoba, ACNP
# 13                        Las Palmas Wound Management
# 14            Las Palmas Del Sol Surgical Specialists
#
#                Associated_Doctors           Phone  \
# 0    No Individual Doctors Listed  (915) 779-3681
# 1    No Individual Doctors Listed  (575) 874-9338
# 2   Dr. Oscar M. Aguilar, MD, MPH  (915) 532-8666
# 3    No Individual Doctors Listed  (915) 910-4661
# 4    No Individual Doctors Listed  (915) 910-4661
# 5    No Individual Doctors Listed  (915) 629-9525
# 6    No Individual Doctors Listed  (915) 533-1960
# 7    No Individual Doctors Listed  (915) 533-1960
# 8    No Individual Doctors Listed  (915) 757-0792
# 9    No Individual Doctors Listed  (915) 594-8070
# 10   No Individual Doctors Listed  (915) 995-7230
# 11          Michael Velasquez, DO  (915) 248-1793
# 12   No Individual Doctors Listed  (915) 248-1793
# 13   No Individual Doctors Listed  (915) 264-7901
# 14         Jennifer R. George, MD  (915) 263-7080
#
#                                               Address              Type
# 0   1 Butterfield Trail Blvd suite b, El Paso, TX ...  Medical Facility
# 1   100 Airport Rd, Santa Teresa, NM 88008, United...  Medical Facility
# 2   100 Executive Center Blvd A, El Paso, TX 79902...  Private Practice
# 3   100 Executive Center Blvd Suite B, El Paso, TX...  Medical Facility
# 4   100 Executive Center Blvd Suite B, El Paso, TX...  Medical Facility
# 5   1000 Kastrin St, El Paso, TX 79907, United States  Medical Facility
# 6    1000 N Mesa St, El Paso, TX 79902, United States  Medical Facility
# 7    1000 N Mesa St, El Paso, TX 79902, United States  Medical Facility
# 8   10004 Kenworthy St, El Paso, TX 79924, United ...  Medical Facility
# 9     10048 Suez Dr, El Paso, TX 79925, United States  Medical Facility
# 10  10064 Alameda Ave, Socorro, TX 79927, United S...  Medical Facility
# 11  10090 Rushing Rd B, El Paso, TX 79924, United ...  Medical Facility
# 12  10090 Rushing Rd, El Paso, TX 79924, United St...  Medical Facility
# 13  101 Rim Rd #200, El Paso, TX 79902, United States  Medical Facility
# 14  101 Rim Rd 300 B, El Paso, TX 79902, United St...  Medical Facility

# %%
# Save
final_mapped_df.to_csv('el_paso_doctors_mapped_to_clinics.csv', index=False)

print(f"Mapped {len(final_mapped_df)} unique locations.")
print(final_mapped_df.head())
